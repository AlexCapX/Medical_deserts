# %%
# Import librairies

import pandas as pd

import plotly.figure_factory as ff

# %%
# URL of the CSV file of INSEE data
insee_url = 'https://medical-deserts-project.s3.eu-north-1.amazonaws.com/insee_clean.csv'

# Read the CSV file from the URL into a DataFrame
insee_df = pd.read_csv(insee_url, sep = ',', encoding='utf-8')

# %%
# Remove useless columns
insee_df = insee_df.drop(["APL aux médecins généralistes de 65 ans et moins", "APL aux médecins généralistes de 62 ans et moins"], axis=1)

# APL column at the end of dataset
APL_column = insee_df.pop("APL aux médecins généralistes (sans borne d'âge)")
insee_df["APL aux médecins généralistes (sans borne d'âge)"] = APL_column

# %%
pd.set_option("display.max_columns", None)

print('Number of rows :', insee_df.shape[0])
print('Number of columns :', insee_df.shape[1])
print()

# Show first rows of the dataset
print('First rows of the dataset :')
display(insee_df.head())
print()

# Dataset statistics
print('Basics statistics :')
summary_stats_all = insee_df.describe(include='all')
display(summary_stats_all)
print()

# Missing values percentage
missing_percentages = (insee_df.isna().mean() * 100).round(2)
print('Percentage of missing values: ')
print(missing_percentages)
# Out:
# Number of rows : 38590
# Number of columns : 88
#
# First rows of the dataset :
#    Dynamique Entrepreneuriale  Dynamique Entrepreneuriale Service et Commerce  \
# 0                        57.0                                            23.0
# 1                        45.0                                             4.0
# 2                       634.0                                           828.0
# 3                       113.0                                            62.0
# 4                        42.0                                             1.0
#
#    Synergie Médicale COMMUNE           SEG Croissance POP  \
# 0                        114  en croissance démographique
# 1                        143  en croissance démographique
# 2                        366  en croissance démographique
# 3                        132  en croissance démographique
# 4                        121  en croissance démographique
#
# ...

# %%
# Select only numerical columns for the correlation matrix
numeric_columns = insee_df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
corr_matrix = numeric_columns.corr().round(2)

fig = ff.create_annotated_heatmap(corr_matrix.values,
                                  x=corr_matrix.columns.tolist(),
                                  y=corr_matrix.index.tolist())

fig.update_layout(height=2400, width=3200)

fig.show()

# %%
# Select the correlation indices for the "APL" column
apl_correlation = corr_matrix["APL aux médecins généralistes (sans borne d'âge)"]

# Sort the correlation indices in descending order
sorted_correlation = apl_correlation.abs().sort_values(ascending=False)

# Display the correlation indices in order
print(sorted_correlation.head(25))
# Out:
# APL aux médecins généralistes (sans borne d'âge)                   1.00
# Score Urbanité                                                     0.26
# Nb Hotel                                                           0.15
# Nb propriétaire                                                    0.15
# Pop 45-59 ans en 2014 (princ)                                      0.15
# Pop 60-74 ans en 2014 (princ)                                      0.15
# Pop 15 ans ou plus Retraités  en 2014 (compl)                      0.15
# Pop 15 ans ou plus Ouvriers en 2014 (compl)                        0.14
# Pop 15 ans ou plus Employés en 2014 (compl)                        0.14
# Nb Création Industrielles                                          0.14
# Pop 75-89 ans en 2014 (princ)                                      0.14
# Nb Entreprises Secteur Industrie                                   0.14
# Nb Entreprises Secteur Construction                                0.14
# ...

# %%
corr_matrix = numeric_columns.corr().round(2)

high_corr_list = []
cols = corr_matrix.columns

for j in cols:
    for i, item in corr_matrix[j].items():
        if (i!=j) and abs(item) > 0.9:
            high_corr_list.append((i,j))
high_corr_list

no_keep = [high_corr_list[i][0] for i in range(len(high_corr_list)) if i%2 == 0]
print("Columns to be dropped:", no_keep)
# Out:
# Columns to be dropped: ['Dynamique Entrepreneuriale Service et Commerce', 'Indice Démographique', 'Nb Résidences Principales', 'Nb Logement', 'Nb Occupants Résidence Principale', 'Nb Entreprises Secteur Commerce', 'Nb Entreprises Secteur Industrie', 'Nb Création Industrielles', 'Nb Création Commerces', 'Nb Education, santé, action sociale', 'Nb Santé, action sociale', 'Population en 2014 (princ)', 'Pop 15-29 ans en 2014 (princ)', 'Pop 45-59 ans en 2014 (princ)', 'Pop 75-89 ans en 2014 (princ)', 'Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)', 'Pop 15 ans ou plus Employés en 2014 (compl)', 'Pop 15 ans ou plus Retraités  en 2014 (compl)', 'Dynamique Entrepreneuriale', 'Indice Démographique', 'Nb Résidences Principales', 'Nb Logement', 'Nb Occupants Résidence Principale', 'Nb Entreprises Secteur Commerce', 'Nb Entreprises Secteur Industrie', 'Nb Création Industrielles', 'Nb Création Commerces', 'Nb Education, santé, action sociale', 'Nb Santé, action sociale', 'Populat
# ...

# %%
# Remove columns to be dropped
numeric_columns_filtered = insee_df.select_dtypes(include=['float64', 'int64']).drop(columns=no_keep)

# Re-calculate the correlation matrix
corr_matrix_filtered = numeric_columns_filtered.corr().round(2)

print("New correlation matrix:")
print(corr_matrix_filtered)

fig = ff.create_annotated_heatmap(corr_matrix_filtered.values,
                                  x=corr_matrix_filtered.columns.tolist(),
                                  y=corr_matrix_filtered.index.tolist())

fig.update_layout(height=1200, width=1600)

fig.show()
# Out:
# New correlation matrix:
#                                                     Nb Infirmiers Libéraux BV  \
# Nb Infirmiers Libéraux BV                                                1.00
# Nb pharmaciens Libéraux BV                                               0.83
# Densité Médicale BV                                                     -0.15
# Score équipement de santé BV                                             0.48
# Nb Résidences Secondaires                                                0.00
# Moyenne Revenus Fiscaux Départementaux                                  -0.01
# Moyenne Revenus Fiscaux Régionaux                                        0.08
# Dep Moyenne Salaires Horaires                                           -0.06
# Dep Moyenne Salaires Cadre Horaires                                     -0.09
# Dep Moyenne Salaires Prof Intermédiaire Horaires                        -0.11
# Dep Moyenne Salaires Employé Horaires                                   -0.13
# ...

# %%
# Select the correlation indices for the "APL" column
apl_correlation = corr_matrix["APL aux médecins généralistes (sans borne d'âge)"]

# Sort the correlation indices in descending order
sorted_correlation = apl_correlation.abs().sort_values(ascending=False)

# Display the correlation indices in order
print(sorted_correlation.head(25))
# Out:
# APL aux médecins généralistes (sans borne d'âge)                   1.00
# Score Urbanité                                                     0.26
# Nb Hotel                                                           0.15
# Nb propriétaire                                                    0.15
# Pop 45-59 ans en 2014 (princ)                                      0.15
# Pop 60-74 ans en 2014 (princ)                                      0.15
# Pop 15 ans ou plus Retraités  en 2014 (compl)                      0.15
# Pop 15 ans ou plus Ouvriers en 2014 (compl)                        0.14
# Pop 15 ans ou plus Employés en 2014 (compl)                        0.14
# Nb Création Industrielles                                          0.14
# Pop 75-89 ans en 2014 (princ)                                      0.14
# Nb Entreprises Secteur Industrie                                   0.14
# Nb Entreprises Secteur Construction                                0.14
# ...
