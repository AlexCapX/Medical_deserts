# %%
# Import librairies

import pandas as pd

pd.set_option("display.max_columns", None)

# %%
stat_pop_generale = pd.read_excel('https://medical-deserts.s3.eu-west-3.amazonaws.com/statistiques+g%C3%A9n%C3%A9rales+population+2014.xls')

# %%
stat_pop_generale.head()
# Out:
#   CODGEO  REG DEP                   LIBGEO  Population en 2014 (princ)  \
# 0  01001   84  01  L'Abergement-Clémenciat                       767.0
# 1  01002   84  01    L'Abergement-de-Varey                       239.0
# 2  01004   84  01        Ambérieu-en-Bugey                     14022.0
# 3  01005   84  01      Ambérieux-en-Dombes                      1627.0
# 4  01006   84  01                  Ambléon                       109.0
#
#    Pop 0-14 ans en 2014 (princ)  Pop 15-29 ans en 2014 (princ)  \
# 0                    161.000000                     102.000000
# 1                     54.094650                      27.539095
# 2                   2778.161034                    2958.443568
# 3                    335.650401                     251.235330
# 4                     11.890909                      15.854545
#
#    Pop 30-44 ans en 2014 (princ)  Pop 45-59 ans en 2014 (princ)  \
# 0                     132.000000                     189.000000
# ...

# %%
stat_pop_generale.shape
# Out:
# (35868, 108)

# %%
stat_pop_generale.dtypes
# Out:
# CODGEO                                                      object
# REG                                                          int64
# DEP                                                         object
# LIBGEO                                                      object
# Population en 2014 (princ)                                 float64
#                                                             ...
# Pop 55 ans ou plus Prof. intermédiaires en 2014 (compl)    float64
# Pop 55 ans ou plus Employés en 2014 (compl)                float64
# Pop 55 ans ou plus Ouvriers en 2014 (compl)                float64
# Pop 55 ans ou plus Retraités en 2014 (compl)               float64
# Pop 55 ans ou plus Autres en 2014 (compl)                  float64
# Length: 108, dtype: object

# %%
stat_pop_generale_work = stat_pop_generale.copy()

# %%
first_column_to_drop = stat_pop_generale_work.columns.get_loc("Pop Hommes en 2014 (princ)")
last_column_to_drop = stat_pop_generale_work.columns.get_loc("Pop 55 ans ou plus habitant 1 an avt autre commune en 2014 (princ)")

# %%
stat_pop_generale_work.drop(stat_pop_generale_work.columns[first_column_to_drop:last_column_to_drop+1], axis=1, inplace=True)

# %%
stat_pop_generale_work.head()
# Out:
#   CODGEO  REG DEP                   LIBGEO  Population en 2014 (princ)  \
# 0  01001   84  01  L'Abergement-Clémenciat                       767.0
# 1  01002   84  01    L'Abergement-de-Varey                       239.0
# 2  01004   84  01        Ambérieu-en-Bugey                     14022.0
# 3  01005   84  01      Ambérieux-en-Dombes                      1627.0
# 4  01006   84  01                  Ambléon                       109.0
#
#    Pop 0-14 ans en 2014 (princ)  Pop 15-29 ans en 2014 (princ)  \
# 0                    161.000000                     102.000000
# 1                     54.094650                      27.539095
# 2                   2778.161034                    2958.443568
# 3                    335.650401                     251.235330
# 4                     11.890909                      15.854545
#
#    Pop 30-44 ans en 2014 (princ)  Pop 45-59 ans en 2014 (princ)  \
# 0                     132.000000                     189.000000
# ...

# %%
first_column_to_drop = stat_pop_generale_work.columns.get_loc("Pop 15 ans ou plus Hommes en 2014 (compl)")
last_column_to_drop = stat_pop_generale_work.columns.get_loc("Pop 15 ans ou plus Femmes Autres en 2014 (compl)")

# %%
stat_pop_generale_work.drop(stat_pop_generale_work.columns[first_column_to_drop:last_column_to_drop + 1], axis=1, inplace=True)

# %%
stat_pop_generale_work.head()
# Out:
#   CODGEO  REG DEP                   LIBGEO  Population en 2014 (princ)  \
# 0  01001   84  01  L'Abergement-Clémenciat                       767.0
# 1  01002   84  01    L'Abergement-de-Varey                       239.0
# 2  01004   84  01        Ambérieu-en-Bugey                     14022.0
# 3  01005   84  01      Ambérieux-en-Dombes                      1627.0
# 4  01006   84  01                  Ambléon                       109.0
#
#    Pop 0-14 ans en 2014 (princ)  Pop 15-29 ans en 2014 (princ)  \
# 0                    161.000000                     102.000000
# 1                     54.094650                      27.539095
# 2                   2778.161034                    2958.443568
# 3                    335.650401                     251.235330
# 4                     11.890909                      15.854545
#
#    Pop 30-44 ans en 2014 (princ)  Pop 45-59 ans en 2014 (princ)  \
# 0                     132.000000                     189.000000
# ...

# %%
first_column_to_drop = stat_pop_generale_work.columns.get_loc('Pop 15-24 ans en 2014 (compl)')

# %%
stat_pop_generale_work.drop(stat_pop_generale_work.columns[first_column_to_drop:], axis=1, inplace=True)

# %%
stat_pop_generale_work.head()
# Out:
#   CODGEO  REG DEP                   LIBGEO  Population en 2014 (princ)  \
# 0  01001   84  01  L'Abergement-Clémenciat                       767.0
# 1  01002   84  01    L'Abergement-de-Varey                       239.0
# 2  01004   84  01        Ambérieu-en-Bugey                     14022.0
# 3  01005   84  01      Ambérieux-en-Dombes                      1627.0
# 4  01006   84  01                  Ambléon                       109.0
#
#    Pop 0-14 ans en 2014 (princ)  Pop 15-29 ans en 2014 (princ)  \
# 0                    161.000000                     102.000000
# 1                     54.094650                      27.539095
# 2                   2778.161034                    2958.443568
# 3                    335.650401                     251.235330
# 4                     11.890909                      15.854545
#
#    Pop 30-44 ans en 2014 (princ)  Pop 45-59 ans en 2014 (princ)  \
# 0                     132.000000                     189.000000
# ...

# %%
stat_pop_generale_work.drop(stat_pop_generale_work[['REG', 'DEP', 'LIBGEO']], axis=1, inplace=True)

# %%
stat_pop_generale_work.head()
# Out:
#   CODGEO  Population en 2014 (princ)  Pop 0-14 ans en 2014 (princ)  \
# 0  01001                       767.0                    161.000000
# 1  01002                       239.0                     54.094650
# 2  01004                     14022.0                   2778.161034
# 3  01005                      1627.0                    335.650401
# 4  01006                       109.0                     11.890909
#
#    Pop 15-29 ans en 2014 (princ)  Pop 30-44 ans en 2014 (princ)  \
# 0                     102.000000                     132.000000
# 1                      27.539095                      68.847737
# 2                    2958.443568                    2641.519143
# 3                     251.235330                     322.586164
# 4                      15.854545                      14.863636
#
#    Pop 45-59 ans en 2014 (princ)  Pop 60-74 ans en 2014 (princ)  \
# 0                     189.000000                     125.000000
# ...

# %%
# Convert columns to int
columns_to_convert = stat_pop_generale_work.columns.drop('CODGEO')
stat_pop_generale_work[columns_to_convert] = stat_pop_generale_work[columns_to_convert].round().astype(int)

# %%
stat_pop_generale_work.head()
# Out:
#   CODGEO  Population en 2014 (princ)  Pop 0-14 ans en 2014 (princ)  \
# 0  01001                         767                           161
# 1  01002                         239                            54
# 2  01004                       14022                          2778
# 3  01005                        1627                           336
# 4  01006                         109                            12
#
#    Pop 15-29 ans en 2014 (princ)  Pop 30-44 ans en 2014 (princ)  \
# 0                            102                            132
# 1                             28                             69
# 2                           2958                           2642
# 3                            251                            323
# 4                             16                             15
#
#    Pop 45-59 ans en 2014 (princ)  Pop 60-74 ans en 2014 (princ)  \
# 0                            189                            125
# ...

# %%
stat_emploi = pd.read_excel('https://medical-deserts.s3.eu-west-3.amazonaws.com/statistiques+emploi+population+2014.xls')

# %%
stat_emploi_work = stat_emploi.copy()

# %%
stat_emploi_work['taux chômage(15-64 ans)'] =100*stat_emploi_work['Chômeurs 15-64 ans en 2014 (princ)']/stat_emploi_work['Actifs 15-64 ans en 2014 (princ)']

# %%
stat_emploi_work.head()
# Out:
#   CODGEO  REG DEP                   LIBGEO  Pop 15-64 ans en 2014 (princ)  \
# 0  01001   84  01  L'Abergement-Clémenciat                     463.000000
# 1  01002   84  01    L'Abergement-de-Varey                     141.629630
# 2  01004   84  01        Ambérieu-en-Bugey                    8962.842157
# 3  01005   84  01      Ambérieux-en-Dombes                    1043.129092
# 4  01006   84  01                  Ambléon                      71.345455
#
#    Pop 15-24 ans en 2014 (princ)  Pop 25-54 ans en 2014 (princ)  \
# 0                      69.000000                     299.000000
# 1                      14.753086                     102.288066
# 2                    1847.659537                    5522.723973
# 3                     180.889438                     656.226683
# 4                       9.909091                      42.609091
#
#    Pop 55-64 ans en 2014 (princ)  Pop 15-64 ans Hommes en 2014 (princ)  \
# ...

# %%
stat_emploi_work = stat_emploi_work[['CODGEO', 'taux chômage(15-64 ans)']]

# %%
stat_emploi_work.head()
# Out:
#   CODGEO  taux chômage(15-64 ans)
# 0  01001                 8.776596
# 1  01002                 8.130081
# 2  01004                15.859777
# 3  01005                 7.875895
# 4  01006                13.793103

# %%
stat_pop_generale_work = stat_pop_generale_work.merge(stat_emploi_work[["CODGEO", "taux chômage(15-64 ans)"]], on="CODGEO", how="left")

# %%
stat_pop_generale_work.head()
# Out:
#   CODGEO  Population en 2014 (princ)  Pop 0-14 ans en 2014 (princ)  \
# 0  01001                         767                           161
# 1  01002                         239                            54
# 2  01004                       14022                          2778
# 3  01005                        1627                           336
# 4  01006                         109                            12
#
#    Pop 15-29 ans en 2014 (princ)  Pop 30-44 ans en 2014 (princ)  \
# 0                            102                            132
# 1                             28                             69
# 2                           2958                           2642
# 3                            251                            323
# 4                             16                             15
#
#    Pop 45-59 ans en 2014 (princ)  Pop 60-74 ans en 2014 (princ)  \
# 0                            189                            125
# ...

# %%
print('Number of rows :', stat_pop_generale_work.shape[0])
print('Number of columns :', stat_pop_generale_work.shape[1])
print()


# Dataset statistics
print('Basics statistics :')
summary_stats_all = stat_pop_generale_work.describe(include='all')
display(summary_stats_all)
print()

# Missing values percentage
missing_percentages = (stat_pop_generale_work.isna().mean() * 100).round(2)
print('Percentage of missing values: ')
print(missing_percentages)
# Out:
# Number of rows : 35868
# Number of columns : 19
#
# Basics statistics :
#        CODGEO  Population en 2014 (princ)  Pop 0-14 ans en 2014 (princ)  \
# count   35868                35868.000000                  35868.000000
# unique  35868                         NaN                           NaN
# top     01001                         NaN                           NaN
# freq        1                         NaN                           NaN
# mean      NaN                 1833.225717                    337.936712
# std       NaN                 8375.863365                   1435.731456
# min       NaN                    0.000000                      0.000000
# 25%       NaN                  197.750000                     34.000000
# 50%       NaN                  444.000000                     84.000000
# 75%       NaN                 1112.000000                    213.000000
# max       NaN               466297.000000                  67674.000000
#
# ...

# %%
#Drop null values from dataset 

stat_pop_generale_work.dropna(inplace=True)
