# %%
# Import librairies

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression

import plotly.express as px

# %%
# URL of the CSV file of INSEE data
insee_url = 'https://medical-deserts-project.s3.eu-north-1.amazonaws.com/insee_clean.csv'

# Read the CSV file from the URL into a DataFrame
insee_df_original = pd.read_csv(insee_url, sep = ',', encoding='utf-8')

# %%
insee_df = insee_df_original.copy()

# %%
pd.set_option("display.max_columns", None)

# %%
# Remove useless columns
insee_df = insee_df.drop(["APL aux médecins généralistes de 65 ans et moins", "APL aux médecins généralistes de 62 ans et moins"], axis=1)

# APL column at the end of dataset
insee_df["SEG Croissance POP"] = insee_df.pop("SEG Croissance POP")
insee_df["Urbanité Ruralité"] = insee_df.pop("Urbanité Ruralité")
insee_df["Dynamique Démographique BV"] = insee_df.pop("Dynamique Démographique BV")
insee_df["Environnement Démographique"] = insee_df.pop("Environnement Démographique")
insee_df["Fidélité"] = insee_df.pop("Fidélité")
insee_df["Seg Cap Fiscale"] = insee_df.pop("Seg Cap Fiscale")
insee_df["Seg Dyn Entre"] = insee_df.pop("Seg Dyn Entre")
insee_df["DYN SetC"] = insee_df.pop("DYN SetC")
insee_df["Catégorie commune dans aire d'attraction des villes 2020"] = insee_df.pop("Catégorie commune dans aire d'attraction des villes 2020")
insee_df["Tranche détaillée d'aire d'attraction des villes 2020"] = insee_df.pop("Tranche détaillée d'aire d'attraction des villes 2020")
insee_df["Libellé degré de densité"] = insee_df.pop("Libellé degré de densité")
insee_df["APL aux médecins généralistes (sans borne d'âge)"] = insee_df.pop("APL aux médecins généralistes (sans borne d'âge)")

# Rename APL column
insee_df.rename(columns={"APL aux médecins généralistes (sans borne d'âge)": "APL"}, inplace=True)

# %%
print('Number of rows :', insee_df.shape[0])
print('Number of columns :', insee_df.shape[1])
print()

# Show first rows of the dataset
print('First rows of the dataset :')
display(insee_df.head())
print()

# Dataset statistics
print('Basics statistics :')
summary_stats_all = insee_df.describe(include='all')
display(summary_stats_all)
print()

# Missing values percentage
missing_percentages = (insee_df.isna().mean() * 100).round(2)
print('Percentage of missing values: ')
print(missing_percentages)
# Out:
# Number of rows : 38590
# Number of columns : 88
#
# First rows of the dataset :
#    Dynamique Entrepreneuriale  Dynamique Entrepreneuriale Service et Commerce  \
# 0                        57.0                                            23.0
# 1                        45.0                                             4.0
# 2                       634.0                                           828.0
# 3                       113.0                                            62.0
# 4                        42.0                                             1.0
#
#    Synergie Médicale COMMUNE  Nb Omnipraticiens BV  Nb Infirmiers Libéraux BV  \
# 0                        114                     9                         14
# 1                        143                    31                         36
# 2                        366                    31                         36
# 3                        132                    12                         12
# 4                        121                    26                         21
#
#    Nb dentistes Libéraux BV  Nb pharmaciens Libéraux BV  Densité Médicale BV  \
# 0                         7                           7             0.092860
# 1                        18                          18             0.099229
# 2                        18                          18             0.099229
# 3                         6                           6             1.000000
# 4                        10                          10             0.100905
#
#    Score équipement de santé BV  Indice Démographique  Nb Ménages  \
# 0                             4              44.19769         247
# 1                             4              10.18071          67
# 2                             4             696.92134        4640
# 3                             1              85.77400         473
# 4                             3               5.24276          41
#
#    Nb Résidences Principales  Nb propriétaire  Nb Logement  \
# 0                        248              196          289
# 1                         67               61          142
# 2                       4635             1968         5184
# 3                        473              344          505
# 4                         41               28           57
#
#    Nb Résidences Secondaires  Nb Log Vacants  \
# 0                         32               9
# 1                         71               4
# 2                        135             414
# 3                         14              18
# 4                         13               3
#
#    Nb Occupants Résidence Principale  Nb Entreprises Secteur Services  \
# 0                                728                              7.0
# 1                                168                              4.0
# 2                              11015                            342.0
# 3                               1406                             22.0
# 4                                 86                              1.0
#
#    Nb Entreprises Secteur Commerce  Nb Entreprises Secteur Construction  \
# 0                             11.0                                  2.0
# 1                              0.0                                  1.0
# 2                            301.0                                 58.0
# 3                             26.0                                 17.0
# 4                              0.0                                  0.0
#
#    Nb Entreprises Secteur Industrie  Nb Création Enteprises  \
# 0                               2.0                     4.0
# 1                               0.0                     1.0
# 2                             108.0                    83.0
# 3                              10.0                     6.0
# 4                               0.0                     0.0
#
#    Nb Création Industrielles  Nb Création Construction  Nb Création Commerces  \
# 0                        0.0                       2.0                    1.0
# 1                        0.0                       0.0                    0.0
# 2                        4.0                      14.0                   27.0
# 3                        0.0                       4.0                    2.0
# 4                        0.0                       0.0                    0.0
#
#    Nb Création Services  Moyenne Revenus Fiscaux Départementaux  \
# 0                   1.0                                   12509
# 1                   1.0                                   12509
# 2                  38.0                                   12509
# 3                   0.0                                   12509
# 4                   0.0                                   12509
#
#    Moyenne Revenus Fiscaux Régionaux  Dep Moyenne Salaires Horaires  \
# 0                              10458                      11.410345
# 1                              10458                      11.410345
# 2                              10458                      11.410345
# 3                              10458                      11.410345
# 4                              10458                      11.410345
#
#    Dep Moyenne Salaires Cadre Horaires  \
# 0                            21.963793
# 1                            21.963793
# 2                            21.963793
# 3                            21.963793
# 4                            21.963793
#
#    Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# 0                                         12.558621
# 1                                         12.558621
# 2                                         12.558621
# 3                                         12.558621
# 4                                         12.558621
#
#    Dep Moyenne Salaires Employé Horaires  \
# 0                               8.743103
# 1                               8.743103
# 2                               8.743103
# 3                               8.743103
# 4                               8.743103
#
#    Dep Moyenne Salaires Ouvrié Horaires  Reg Moyenne Salaires Horaires  \
# 0                              9.268966                      11.873022
# 1                              9.268966                      11.873022
# 2                              9.268966                      11.873022
# 3                              9.268966                      11.873022
# 4                              9.268966                      11.873022
#
#    Reg Moyenne Salaires Cadre Horaires  \
# 0                             21.78783
# 1                             21.78783
# 2                             21.78783
# 3                             21.78783
# 4                             21.78783
#
#    Reg Moyenne Salaires Prof Intermédiaire Horaires  \
# 0                                         12.704057
# 1                                         12.704057
# 2                                         12.704057
# 3                                         12.704057
# 4                                         12.704057
#
#    Reg Moyenne Salaires Employé Horaires  \
# 0                               8.783164
# 1                               8.783164
# 2                               8.783164
# 3                               8.783164
# 4                               8.783164
#
#    Reg Moyenne Salaires Ouvrié Horaires  Valeur ajoutée régionale  \
# 0                               9.30142               86957.45836
# 1                               9.30142               86957.45836
# 2                               9.30142               86957.45836
# 3                               9.30142               86957.45836
# 4                               9.30142               86957.45836
#
#    Nb Logement Secondaire et Occasionnel  Nb Hotel  Capacité Hotel  \
# 0                                   32.0       0.0             0.0
# 1                                   71.0       0.0             0.0
# 2                                  135.0       2.0            52.0
# 3                                   14.0       2.0            17.0
# 4                                   13.0       0.0             0.0
#
#    Nb Camping  Capacité Camping  Taux Propriété  \
# 0         0.0               0.0              67
# 1         0.0               0.0              42
# 2         0.0               0.0              37
# 3         1.0              72.0              68
# 4         0.0               0.0              49
#
#    Dynamique Démographique INSEE  Capacité Fisc  Moyenne Revnus fiscaux  \
# 0                             -1            117                 11483.5
# 1                              0            110                 11483.5
# 2                            -55            250                 11483.5
# 3                             -3            127                 11483.5
# 4                              0            109                 11483.5
#
#    Nb Education, santé, action sociale  Nb Services personnels et domestiques  \
# 0                                  3.0                                    1.0
# 1                                  0.0                                    0.0
# 2                                113.0                                   41.0
# 3                                  5.0                                    2.0
# 4                                  0.0                                    0.0
#
#    Nb Santé, action sociale  Nb Industries des biens intermédiaires  \
# 0                       0.0                                    9364
# 1                       0.0                                    9364
# 2                     118.0                                    9364
# 3                       7.0                                    9364
# 4                       0.0                                    9364
#
#    Nb de Commerce  Nb de Services aux particuliers  \
# 0            9350                             3372
# 1            9350                             3372
# 2            9350                             3372
# 3            9350                             3372
# 4            9350                             3372
#
#    Nb institution de Education, santé, action sociale, administration  \
# 0                                              15105
# 1                                              15105
# 2                                              15105
# 3                                              15105
# 4                                              15105
#
#    PIB Régionnal  Score Croissance Entrepreneuriale   latitude  longitude  \
# 0         173681                            0.01585  46.153721   4.925850
# 1         173681                            0.00173  46.009606   5.428088
# 2         173681                            0.38471  45.961049   5.372275
# 3         173681                            0.02824  45.996164   4.911967
# 4         173681                            0.00000  45.749886   5.594585
#
#    Population en 2014 (princ)  Pop 0-14 ans en 2014 (princ)  \
# 0                       767.0                         161.0
# 1                       239.0                          54.0
# 2                     14022.0                        2778.0
# 3                      1627.0                         336.0
# 4                       109.0                          12.0
#
#    Pop 15-29 ans en 2014 (princ)  Pop 30-44 ans en 2014 (princ)  \
# 0                          102.0                          132.0
# 1                           28.0                           69.0
# 2                         2958.0                         2642.0
# 3                          251.0                          323.0
# 4                           16.0                           15.0
#
#    Pop 45-59 ans en 2014 (princ)  Pop 60-74 ans en 2014 (princ)  \
# 0                          189.0                          125.0
# 1                           36.0                           33.0
# 2                         2603.0                         1853.0
# 3                          376.0                          232.0
# 4                           29.0                           27.0
#
#    Pop 75-89 ans en 2014 (princ)  Pop 15 ans ou plus en 2014 (compl)  \
# 0                           53.0                               605.0
# 1                           17.0                               192.0
# 2                         1045.0                             11228.0
# 3                           99.0                              1337.0
# 4                           10.0                                89.0
#
#    Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)  \
# 0                                               15.0
# 1                                                0.0
# 2                                                3.0
# 3                                                5.0
# 4                                                0.0
#
#    Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)  \
# 0                                               20.0
# 1                                               20.0
# 2                                              334.0
# 3                                               60.0
# 4                                                0.0
#
#    Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)  \
# 0                                               75.0
# 1                                               15.0
# 2                                              743.0
# 3                                              106.0
# 4                                                5.0
#
#    Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)  \
# 0                                               95.0
# 1                                               25.0
# 2                                             1777.0
# 3                                              231.0
# 4                                               25.0
#
#    Pop 15 ans ou plus Employés en 2014 (compl)  \
# 0                                        100.0
# 1                                         39.0
# 2                                       1918.0
# 3                                        241.0
# 4                                         15.0
#
#    Pop 15 ans ou plus Ouvriers en 2014 (compl)  \
# 0                                        125.0
# 1                                         10.0
# 2                                       1818.0
# 3                                        231.0
# 4                                         15.0
#
#    Pop 15 ans ou plus Retraités  en 2014 (compl)  \
# 0                                          145.0
# 1                                           64.0
# 2                                         2878.0
# 3                                          312.0
# 4                                           25.0
#
#    Pop 15 ans ou plus Autres en 2014 (compl)  taux chômage(15-64 ans)  \
# 0                                       30.0                 8.776596
# 1                                       20.0                 8.130081
# 2                                     1757.0                15.859777
# 3                                      151.0                 7.875895
# 4                                        5.0                13.793103
#
#             SEG Croissance POP           Urbanité Ruralité  \
# 0  en croissance démographique  Com rurale < 2 000 m habts
# 1  en croissance démographique  Com rurale < 2 000 m habts
# 2  en croissance démographique            Com < 50 m habts
# 3  en croissance démographique  Com rurale < 2 000 m habts
# 4  en croissance démographique  Com rurale < 2 000 m habts
#
#                           Dynamique Démographique BV  \
# 0  1.Accroissement par excédent naturel et migrat...
# 1  1.Accroissement par excédent naturel et migrat...
# 2  1.Accroissement par excédent naturel et migrat...
# 3                                       Grande Ville
# 4            3.Accroissement par excédent migratoire
#
#                       Environnement Démographique        Fidélité  \
# 0   Bassin Industriel en croissance démographique  Pop Sédentaire
# 1  Bassin Résidentiel en croissance démographique  Pop Sédentaire
# 2  Bassin Résidentiel en croissance démographique      Pop Mobile
# 3       Bassin Urbain en croissance démographique      Pop Mobile
# 4  Bassin Résidentiel en croissance démographique  Pop Sédentaire
#
#      Seg Cap Fiscale         Seg Dyn Entre  \
# 0  Fiscalité moyenne      Faible dynamique
# 1  Fiscalité moyenne      Faible dynamique
# 2  Fiscalité moyenne  Dynamique Economique
# 3  Fiscalité moyenne     Moyenne dynamique
# 4  Fiscalité moyenne      Faible dynamique
#
#                                  DYN SetC  \
# 0            Faible Dynamique Serv et Com
# 1            Faible Dynamique Serv et Com
# 2  Bonne Dynamique Entreprise Serv et Com
# 3            Faible Dynamique Serv et Com
# 4            Faible Dynamique Serv et Com
#
#   Catégorie commune dans aire d'attraction des villes 2020  \
# 0                             Commune de la couronne
# 1                  Commune hors attraction des pôles
# 2                                     Commune-centre
# 3                             Commune de la couronne
# 4                             Commune de la couronne
#
#   Tranche détaillée d'aire d'attraction des villes 2020  \
# 0                  Aire de moins de 10 000 habitants
# 1                 Commune hors attraction des villes
# 2         Aire de 30 000 à moins de 50 000 habitants
# 3  Aire de 1 000 000 d’habitants ou plus (hors Pa...
# 4         Aire de 20 000 à moins de 30 000 habitants
#
#          Libellé degré de densité    APL
# 0        Rural à habitat dispersé  2.293
# 1        Rural à habitat dispersé  2.600
# 2  Centres urbains intermédiaires  4.079
# 3                   Bourgs ruraux  4.378
# 4        Rural à habitat dispersé  1.069
# Basics statistics :
#         Dynamique Entrepreneuriale  \
# count                 38590.000000
# unique                         NaN
# top                            NaN
# freq                           NaN
# mean                    122.059031
# std                     632.827660
# min                       1.000000
# 25%                      20.000000
# 50%                      33.000000
# 75%                      75.000000
# max                   23794.000000
#
#         Dynamique Entrepreneuriale Service et Commerce  \
# count                                     38590.000000
# unique                                             NaN
# top                                                NaN
# freq                                               NaN
# mean                                        131.970614
# std                                         948.912967
# min                                           0.000000
# 25%                                           6.000000
# 50%                                          13.000000
# 75%                                          46.000000
# max                                       33506.000000
#
#         Synergie Médicale COMMUNE  Nb Omnipraticiens BV  \
# count                38590.000000          38590.000000
# unique                        NaN                   NaN
# top                           NaN                   NaN
# freq                          NaN                   NaN
# mean                   107.723218             16.670951
# std                    230.556624             12.968793
# min                     13.000000              1.000000
# 25%                     52.000000              9.000000
# 50%                     72.000000             12.000000
# 75%                    105.000000             19.000000
# max                   8419.000000             76.000000
#
#         Nb Infirmiers Libéraux BV  Nb dentistes Libéraux BV  \
# count                38590.000000              38590.000000
# unique                        NaN                       NaN
# top                           NaN                       NaN
# freq                          NaN                       NaN
# mean                    16.542187                  8.038248
# std                     14.425287                  6.929272
# min                      0.000000                  0.000000
# 25%                      8.000000                  4.000000
# 50%                     12.000000                  6.000000
# 75%                     19.000000                  9.000000
# max                    112.000000                 49.000000
#
#         Nb pharmaciens Libéraux BV  Densité Médicale BV  \
# count                 38590.000000         38590.000000
# unique                         NaN                  NaN
# top                            NaN                  NaN
# freq                           NaN                  NaN
# mean                      8.038248             0.313389
# std                       6.929272             0.383459
# min                       0.000000             0.032518
# 25%                       4.000000             0.083808
# 50%                       6.000000             0.104593
# 75%                       9.000000             0.180691
# max                      49.000000             1.000000
#
#         Score équipement de santé BV  Indice Démographique     Nb Ménages  \
# count                   38590.000000          38590.000000   38590.000000
# unique                           NaN                   NaN            NaN
# top                              NaN                   NaN            NaN
# freq                             NaN                   NaN            NaN
# mean                        2.527961            130.105343     887.095750
# std                         1.320803            706.006127    5452.654165
# min                         0.000000              0.060960       1.000000
# 25%                         1.000000             11.582840      74.000000
# 50%                         3.000000             26.396690     166.000000
# 75%                         4.000000             68.033960     427.000000
# max                         4.000000          23793.657910  199430.000000
#
#         Nb Résidences Principales  Nb propriétaire    Nb Logement  \
# count                38590.000000     38590.000000   38590.000000
# unique                        NaN              NaN            NaN
# top                           NaN              NaN            NaN
# freq                          NaN              NaN            NaN
# mean                   886.984789       457.078751    1074.334672
# std                   5442.792045      2018.634015    6353.290844
# min                      1.000000         0.000000       2.000000
# 25%                     74.000000        58.000000     103.000000
# 50%                    166.000000       127.000000     219.000000
# 75%                    428.000000       310.000000     533.000000
# max                 197669.000000     75394.000000  224809.000000
#
#         Nb Résidences Secondaires  Nb Log Vacants  \
# count                38590.000000    38590.000000
# unique                        NaN             NaN
# top                           NaN             NaN
# freq                          NaN             NaN
# mean                   110.603265       76.746230
# std                    683.544659      632.693386
# min                      0.000000        0.000000
# 25%                      9.000000        5.000000
# 50%                     23.000000       13.000000
# 75%                     56.000000       32.000000
# max                  29330.000000    27420.000000
#
#         Nb Occupants Résidence Principale  Nb Entreprises Secteur Services  \
# count                        38590.000000                     38590.000000
# unique                                NaN                              NaN
# top                                   NaN                              NaN
# freq                                  NaN                              NaN
# mean                          2080.998160                        53.855895
# std                          11205.841451                       388.455819
# min                              1.000000                         0.000000
# 25%                            189.000000                         3.000000
# 50%                            428.000000                         6.000000
# 75%                           1094.000000                        20.000000
# max                         374719.000000                     14312.000000
#
#         Nb Entreprises Secteur Commerce  Nb Entreprises Secteur Construction  \
# count                      38590.000000                         38590.000000
# unique                              NaN                                  NaN
# top                                 NaN                                  NaN
# freq                                NaN                                  NaN
# mean                          48.923944                            12.886033
# std                          351.468468                            62.453891
# min                            0.000000                             0.000000
# 25%                            2.000000                             1.000000
# 50%                            5.000000                             4.000000
# 75%                           16.000000                             9.000000
# max                        13867.000000                          2829.000000
#
#         Nb Entreprises Secteur Industrie  Nb Création Enteprises  \
# count                       38590.000000            38590.000000
# unique                               NaN                     NaN
# top                                  NaN                     NaN
# freq                                 NaN                     NaN
# mean                           17.892459               11.400985
# std                           100.035842               82.514154
# min                             0.000000                0.000000
# 25%                             1.000000                0.000000
# 50%                             3.000000                2.000000
# 75%                            10.000000                5.000000
# max                          3612.000000             3222.000000
#
#         Nb Création Industrielles  Nb Création Construction  \
# count                38590.000000              38590.000000
# unique                        NaN                       NaN
# top                           NaN                       NaN
# freq                          NaN                       NaN
# mean                     0.693807                  1.876315
# std                      3.719735                 13.865073
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                      0.000000                  1.000000
# max                    136.000000                630.000000
#
#         Nb Création Commerces  Nb Création Services  \
# count            38590.000000          38590.000000
# unique                    NaN                   NaN
# top                       NaN                   NaN
# freq                      NaN                   NaN
# mean                 2.931718              5.899145
# std                 19.891236             46.360770
# min                  0.000000              0.000000
# 25%                  0.000000              0.000000
# 50%                  0.000000              1.000000
# 75%                  1.000000              2.000000
# max                759.000000           1803.000000
#
#         Moyenne Revenus Fiscaux Départementaux  \
# count                             38590.000000
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                              10349.030319
# std                                1564.368493
# min                                6282.000000
# 25%                                9523.000000
# 50%                               10159.000000
# 75%                               11072.000000
# max                               16895.000000
#
#         Moyenne Revenus Fiscaux Régionaux  Dep Moyenne Salaires Horaires  \
# count                        38590.000000                   38590.000000
# unique                                NaN                            NaN
# top                                   NaN                            NaN
# freq                                  NaN                            NaN
# mean                         10253.586810                      10.996303
# std                           1086.882824                       0.949628
# min                           7748.000000                       9.862500
# 25%                           9716.000000                      10.400000
# 50%                          10458.000000                      10.708276
# 75%                          11150.000000                      11.321212
# max                          12338.000000                      17.731429
#
#         Dep Moyenne Salaires Cadre Horaires  \
# count                          38590.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                              21.204149
# std                                0.807518
# min                               19.750000
# 25%                               20.686207
# 50%                               21.052500
# 75%                               21.695833
# max                               26.537143
#
#         Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# count                                       38590.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                           12.464435
# std                                             0.377483
# min                                            11.740000
# 25%                                            12.220833
# 50%                                            12.437931
# 75%                                            12.640404
# max                                            14.185000
#
#         Dep Moyenne Salaires Employé Horaires  \
# count                            38590.000000
# unique                                    NaN
# top                                       NaN
# freq                                      NaN
# mean                                 8.662656
# std                                  0.244586
# min                                  8.261905
# 25%                                  8.518750
# 50%                                  8.622581
# 75%                                  8.767647
# max                                  9.742553
#
#         Dep Moyenne Salaires Ouvrié Horaires  Reg Moyenne Salaires Horaires  \
# count                           38590.000000                   38590.000000
# unique                                   NaN                            NaN
# top                                      NaN                            NaN
# freq                                     NaN                            NaN
# mean                                9.053691                      11.167877
# std                                 0.399395                       0.750011
# min                                 8.300000                      10.574510
# 25%                                 8.790698                      10.679167
# 50%                                 9.038462                      10.992609
# 75%                                 9.292500                      11.295855
# max                                10.356579                      14.534118
#
#         Reg Moyenne Salaires Cadre Horaires  \
# count                          38590.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                              21.281051
# std                                0.592066
# min                               20.509549
# 25%                               21.017098
# 50%                               21.101282
# 75%                               21.640496
# max                               23.685098
#
#         Reg Moyenne Salaires Prof Intermédiaire Horaires  \
# count                                       38590.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                           12.519946
# std                                             0.298912
# min                                            12.175380
# 25%                                            12.339819
# 50%                                            12.435217
# 75%                                            12.673103
# max                                            13.655098
#
#         Reg Moyenne Salaires Employé Horaires  \
# count                            38590.000000
# unique                                    NaN
# top                                       NaN
# freq                                      NaN
# mean                                 8.686405
# std                                  0.204727
# min                                  8.453394
# 25%                                  8.569608
# 50%                                  8.634906
# 75%                                  8.783164
# max                                  9.591176
#
#         Reg Moyenne Salaires Ouvrié Horaires  Valeur ajoutée régionale  \
# count                           38590.000000              38590.000000
# unique                                   NaN                       NaN
# top                                      NaN                       NaN
# freq                                     NaN                       NaN
# mean                                9.115599              41731.992599
# std                                 0.295514              46193.354235
# min                                 8.725000               3021.411002
# 25%                                 8.915652              20389.521530
# 50%                                 9.082927              30848.563720
# 75%                                 9.239535              38930.865310
# max                                10.131176             261877.286900
#
#         Nb Logement Secondaire et Occasionnel      Nb Hotel  Capacité Hotel  \
# count                            38590.000000  38590.000000    38590.000000
# unique                                    NaN           NaN             NaN
# top                                       NaN           NaN             NaN
# freq                                      NaN           NaN             NaN
# mean                               110.553537      0.672687       23.236927
# std                                683.459612      4.141992      209.618030
# min                                  0.000000      0.000000        0.000000
# 25%                                  9.000000      0.000000        0.000000
# 50%                                 23.000000      0.000000        0.000000
# 75%                                 56.000000      0.000000        0.000000
# max                              29330.000000    206.000000    13402.000000
#
#           Nb Camping  Capacité Camping  Taux Propriété  \
# count   38590.000000      38590.000000    38590.000000
# unique           NaN               NaN             NaN
# top              NaN               NaN             NaN
# freq             NaN               NaN             NaN
# mean        0.278984         34.060767       57.411791
# std         1.204422        246.912501       15.613730
# min         0.000000          0.000000        0.000000
# 25%         0.000000          0.000000       48.000000
# 50%         0.000000          0.000000       59.000000
# 75%         0.000000          0.000000       69.000000
# max        56.000000      14475.000000      100.000000
#
#         Dynamique Démographique INSEE  Capacité Fisc  Moyenne Revnus fiscaux  \
# count                    38590.000000   38590.000000            38590.000000
# unique                            NaN            NaN                     NaN
# top                               NaN            NaN                     NaN
# freq                              NaN            NaN                     NaN
# mean                        -7.438300       8.614615            10301.308564
# std                         65.947977    2267.481665             1052.613147
# min                      -1929.000000 -140594.000000             7664.000000
# 25%                         -1.000000      72.000000             9643.000000
# 50%                          0.000000      81.000000            10304.500000
# 75%                          0.000000      96.000000            10942.500000
# max                        417.000000     587.000000            12850.000000
#
#         Nb Education, santé, action sociale  \
# count                          38590.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                              14.450998
# std                              112.080711
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                4.000000
# max                             4126.000000
#
#         Nb Services personnels et domestiques  Nb Santé, action sociale  \
# count                            38590.000000              38590.000000
# unique                                    NaN                       NaN
# top                                       NaN                       NaN
# freq                                      NaN                       NaN
# mean                                 4.663980                 15.330707
# std                                 30.743394                113.227901
# min                                  0.000000                  0.000000
# 25%                                  0.000000                  0.000000
# 50%                                  0.000000                  0.000000
# 75%                                  2.000000                  5.000000
# max                               1135.000000               4002.000000
#
#         Nb Industries des biens intermédiaires  Nb de Commerce  \
# count                             38590.000000    38590.000000
# unique                                     NaN             NaN
# top                                        NaN             NaN
# freq                                       NaN             NaN
# mean                               3259.704172     4630.877611
# std                                2586.215602     5041.672809
# min                                  30.000000      342.000000
# 25%                                1935.000000     2425.000000
# 50%                                2576.000000     3333.000000
# 75%                                3268.000000     4858.000000
# max                               10383.000000    28477.000000
#
#         Nb de Services aux particuliers  \
# count                      38590.000000
# unique                              NaN
# top                                 NaN
# freq                                NaN
# mean                        1881.694195
# std                         3397.388840
# min                          187.000000
# 25%                          776.000000
# 50%                          925.000000
# 75%                         1552.000000
# max                        19139.000000
#
#         Nb institution de Education, santé, action sociale, administration  \
# count                                        38590.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                          8076.407126
# std                                           6993.429302
# min                                            828.000000
# 25%                                           4406.000000
# 50%                                           6903.000000
# 75%                                           8683.000000
# max                                          39842.000000
#
#         PIB Régionnal  Score Croissance Entrepreneuriale      latitude  \
# count    38590.000000                       38590.000000  38590.000000
# unique            NaN                                NaN           NaN
# top               NaN                                NaN           NaN
# freq              NaN                                NaN           NaN
# mean     81328.806841                           0.045904     46.974702
# std      89322.777725                           0.319206      2.206645
# min       6358.000000                           0.000000     41.435023
# 25%      40484.000000                           0.000000     45.182952
# 50%      55218.000000                           0.003460     47.400393
# 75%      79920.000000                           0.019310     48.826340
# max     500839.000000                          12.351540     51.072906
#
#            longitude  Population en 2014 (princ)  \
# count   38590.000000                38590.000000
# unique           NaN                         NaN
# top              NaN                         NaN
# freq             NaN                         NaN
# mean        2.774471                 2403.482197
# std         2.690440                12563.813825
# min        -5.086014                    1.000000
# 25%         0.669468                  214.000000
# 50%         2.683102                  507.500000
# 75%         4.958665                 1339.000000
# max         9.529052               466297.000000
#
#         Pop 0-14 ans en 2014 (princ)  Pop 15-29 ans en 2014 (princ)  \
# count                   38590.000000                   38590.000000
# unique                           NaN                            NaN
# top                              NaN                            NaN
# freq                             NaN                            NaN
# mean                      430.765924                     453.174216
# std                      2028.827534                    3402.185602
# min                         0.000000                       0.000000
# 25%                        37.000000                      27.000000
# 50%                        94.000000                      68.000000
# 75%                       253.000000                     187.000000
# max                     67674.000000                  149265.000000
#
#         Pop 30-44 ans en 2014 (princ)  Pop 45-59 ans en 2014 (princ)  \
# count                    38590.000000                   38590.000000
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean                       458.560041                     467.768930
# std                       2486.489904                    2120.364937
# min                          0.000000                       0.000000
# 25%                         39.000000                      47.000000
# 50%                         97.000000                     110.000000
# 75%                        255.000000                     286.000000
# max                     100514.000000                   69429.000000
#
#         Pop 60-74 ans en 2014 (princ)  Pop 75-89 ans en 2014 (princ)  \
# count                    38590.000000                   38590.000000
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean                       363.083519                     202.945996
# std                       1621.598590                     983.293809
# min                          0.000000                       0.000000
# 25%                         37.000000                      17.000000
# 50%                         84.000000                      39.000000
# 75%                        222.000000                     111.000000
# max                      56680.000000                   36812.000000
#
#         Pop 15 ans ou plus en 2014 (compl)  \
# count                         38590.000000
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                           1972.782716
# std                           10559.841653
# min                               0.000000
# 25%                             175.000000
# 50%                             410.000000
# 75%                            1084.000000
# max                          398669.000000
#
#         Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)  \
# count                                        38590.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            15.344312
# std                                             29.968274
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              8.000000
# 75%                                             18.000000
# max                                            615.000000
#
#         Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)  \
# count                                        38590.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            67.002047
# std                                            310.565795
# min                                              0.000000
# 25%                                              5.000000
# 50%                                             17.000000
# 75%                                             46.000000
# max                                          11356.000000
#
#         Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)  \
# count                                        38590.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           170.923555
# std                                           1410.328800
# min                                              0.000000
# 25%                                              5.000000
# 50%                                             20.000000
# 75%                                             61.000000
# max                                          68778.000000
#
#         Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)  \
# count                                        38590.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           275.980254
# std                                           1566.104206
# min                                              0.000000
# 25%                                             20.000000
# 50%                                             53.000000
# 75%                                            149.750000
# max                                          65237.000000
#
#         Pop 15 ans ou plus Employés en 2014 (compl)  \
# count                                  38590.000000
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                     324.198575
# std                                     1708.012664
# min                                        0.000000
# 25%                                       25.000000
# 50%                                       65.000000
# 75%                                      176.000000
# max                                    61264.000000
#
#         Pop 15 ans ou plus Ouvriers en 2014 (compl)  \
# count                                  38590.000000
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                     253.273128
# std                                     1065.921715
# min                                        0.000000
# 25%                                       25.000000
# 50%                                       63.000000
# 75%                                      161.000000
# max                                    33792.000000
#
#         Pop 15 ans ou plus Retraités  en 2014 (compl)  \
# count                                    38590.000000
# unique                                            NaN
# top                                               NaN
# freq                                              NaN
# mean                                       533.623063
# std                                       2372.100805
# min                                          0.000000
# 25%                                         52.000000
# 50%                                        119.000000
# 75%                                        324.000000
# max                                      83465.000000
#
#         Pop 15 ans ou plus Autres en 2014 (compl)  taux chômage(15-64 ans)  \
# count                                38590.000000             38590.000000
# unique                                        NaN                      NaN
# top                                           NaN                      NaN
# freq                                          NaN                      NaN
# mean                                   332.432547                10.820448
# std                                   2401.530829                 4.840921
# min                                      0.000000                 0.000000
# 25%                                     20.000000                 7.636364
# 50%                                     48.000000                10.090842
# 75%                                    133.000000                13.303515
# max                                  92678.000000                75.000000
#
#                  SEG Croissance POP           Urbanité Ruralité  \
# count                         38590                       38590
# unique                            2                           6
# top     en croissance démographique  Com rurale < 2 000 m habts
# freq                          38579                       30651
# mean                            NaN                         NaN
# std                             NaN                         NaN
# min                             NaN                         NaN
# 25%                             NaN                         NaN
# 50%                             NaN                         NaN
# 75%                             NaN                         NaN
# max                             NaN                         NaN
#
#        Dynamique Démographique BV  \
# count                       38590
# unique                          7
# top                  Grande Ville
# freq                         9137
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN
#
#                            Environnement Démographique        Fidélité  \
# count                                            38590           38590
# unique                                               7               2
# top     Bassin Résidentiel en croissance démographique  Pop Sédentaire
# freq                                             17697           30448
# mean                                               NaN             NaN
# std                                                NaN             NaN
# min                                                NaN             NaN
# 25%                                                NaN             NaN
# 50%                                                NaN             NaN
# 75%                                                NaN             NaN
# max                                                NaN             NaN
#
#           Seg Cap Fiscale     Seg Dyn Entre                      DYN SetC  \
# count               38590             38590                         38590
# unique                  3                 3                             3
# top     Fiscalité moyenne  Faible dynamique  Faible Dynamique Serv et Com
# freq                30182             30481                         32296
# mean                  NaN               NaN                           NaN
# std                   NaN               NaN                           NaN
# min                   NaN               NaN                           NaN
# 25%                   NaN               NaN                           NaN
# 50%                   NaN               NaN                           NaN
# 75%                   NaN               NaN                           NaN
# max                   NaN               NaN                           NaN
#
#        Catégorie commune dans aire d'attraction des villes 2020  \
# count                                               38590
# unique                                                  5
# top                                Commune de la couronne
# freq                                                26427
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Tranche détaillée d'aire d'attraction des villes 2020  \
# count                                               38590
# unique                                                 17
# top                    Commune hors attraction des villes
# freq                                                 9904
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Libellé degré de densité           APL
# count                      38590  38590.000000
# unique                         7           NaN
# top     Rural à habitat dispersé           NaN
# freq                       19922           NaN
# mean                         NaN      3.292126
# std                          NaN      1.279848
# min                          NaN      0.000000
# 25%                          NaN      2.507000
# 50%                          NaN      3.229000
# 75%                          NaN      4.009000
# max                          NaN     19.685000
# Percentage of missing values:
# Dynamique Entrepreneuriale                                  0.0
# Dynamique Entrepreneuriale Service et Commerce              0.0
# Synergie Médicale COMMUNE                                   0.0
# Nb Omnipraticiens BV                                        0.0
# Nb Infirmiers Libéraux BV                                   0.0
#                                                            ...
# DYN SetC                                                    0.0
# Catégorie commune dans aire d'attraction des villes 2020    0.0
# Tranche détaillée d'aire d'attraction des villes 2020       0.0
# Libellé degré de densité                                    0.0
# APL                                                         0.0
# Length: 88, dtype: float64

# %%
# Separate target variable Y from features X
print("Separating labels from features...")
target_variable = "APL"

X = insee_df.drop(target_variable, axis = 1)
Y = insee_df.loc[:,target_variable]

print("...Done.")
print()

print('Y : ')
print(Y.head())
print()
print('X :')
X.head()
# Out:
# Separating labels from features...
# ...Done.
#
# Y :
# 0    2.293
# 1    2.600
# 2    4.079
# 3    4.378
# 4    1.069
# Name: APL, dtype: float64
#
# X :
#    Dynamique Entrepreneuriale  Dynamique Entrepreneuriale Service et Commerce  \
# 0                        57.0                                            23.0
# 1                        45.0                                             4.0
# 2                       634.0                                           828.0
# 3                       113.0                                            62.0
# 4                        42.0                                             1.0
#
#    Synergie Médicale COMMUNE  Nb Omnipraticiens BV  Nb Infirmiers Libéraux BV  \
# 0                        114                     9                         14
# 1                        143                    31                         36
# 2                        366                    31                         36
# 3                        132                    12                         12
# 4                        121                    26                         21
#
#    Nb dentistes Libéraux BV  Nb pharmaciens Libéraux BV  Densité Médicale BV  \
# 0                         7                           7             0.092860
# 1                        18                          18             0.099229
# 2                        18                          18             0.099229
# 3                         6                           6             1.000000
# 4                        10                          10             0.100905
#
#    Score équipement de santé BV  Indice Démographique  Nb Ménages  \
# 0                             4              44.19769         247
# 1                             4              10.18071          67
# 2                             4             696.92134        4640
# 3                             1              85.77400         473
# 4                             3               5.24276          41
#
#    Nb Résidences Principales  Nb propriétaire  Nb Logement  \
# 0                        248              196          289
# 1                         67               61          142
# 2                       4635             1968         5184
# 3                        473              344          505
# 4                         41               28           57
#
#    Nb Résidences Secondaires  Nb Log Vacants  \
# 0                         32               9
# 1                         71               4
# 2                        135             414
# 3                         14              18
# 4                         13               3
#
#    Nb Occupants Résidence Principale  Nb Entreprises Secteur Services  \
# 0                                728                              7.0
# 1                                168                              4.0
# 2                              11015                            342.0
# 3                               1406                             22.0
# 4                                 86                              1.0
#
#    Nb Entreprises Secteur Commerce  Nb Entreprises Secteur Construction  \
# 0                             11.0                                  2.0
# 1                              0.0                                  1.0
# 2                            301.0                                 58.0
# 3                             26.0                                 17.0
# 4                              0.0                                  0.0
#
#    Nb Entreprises Secteur Industrie  Nb Création Enteprises  \
# 0                               2.0                     4.0
# 1                               0.0                     1.0
# 2                             108.0                    83.0
# 3                              10.0                     6.0
# 4                               0.0                     0.0
#
#    Nb Création Industrielles  Nb Création Construction  Nb Création Commerces  \
# 0                        0.0                       2.0                    1.0
# 1                        0.0                       0.0                    0.0
# 2                        4.0                      14.0                   27.0
# 3                        0.0                       4.0                    2.0
# 4                        0.0                       0.0                    0.0
#
#    Nb Création Services  Moyenne Revenus Fiscaux Départementaux  \
# 0                   1.0                                   12509
# 1                   1.0                                   12509
# 2                  38.0                                   12509
# 3                   0.0                                   12509
# 4                   0.0                                   12509
#
#    Moyenne Revenus Fiscaux Régionaux  Dep Moyenne Salaires Horaires  \
# 0                              10458                      11.410345
# 1                              10458                      11.410345
# 2                              10458                      11.410345
# 3                              10458                      11.410345
# 4                              10458                      11.410345
#
#    Dep Moyenne Salaires Cadre Horaires  \
# 0                            21.963793
# 1                            21.963793
# 2                            21.963793
# 3                            21.963793
# 4                            21.963793
#
#    Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# 0                                         12.558621
# 1                                         12.558621
# 2                                         12.558621
# 3                                         12.558621
# 4                                         12.558621
#
#    Dep Moyenne Salaires Employé Horaires  \
# 0                               8.743103
# 1                               8.743103
# 2                               8.743103
# 3                               8.743103
# 4                               8.743103
#
#    Dep Moyenne Salaires Ouvrié Horaires  Reg Moyenne Salaires Horaires  \
# 0                              9.268966                      11.873022
# 1                              9.268966                      11.873022
# 2                              9.268966                      11.873022
# 3                              9.268966                      11.873022
# 4                              9.268966                      11.873022
#
#    Reg Moyenne Salaires Cadre Horaires  \
# 0                             21.78783
# 1                             21.78783
# 2                             21.78783
# 3                             21.78783
# 4                             21.78783
#
#    Reg Moyenne Salaires Prof Intermédiaire Horaires  \
# 0                                         12.704057
# 1                                         12.704057
# 2                                         12.704057
# 3                                         12.704057
# 4                                         12.704057
#
#    Reg Moyenne Salaires Employé Horaires  \
# 0                               8.783164
# 1                               8.783164
# 2                               8.783164
# 3                               8.783164
# 4                               8.783164
#
#    Reg Moyenne Salaires Ouvrié Horaires  Valeur ajoutée régionale  \
# 0                               9.30142               86957.45836
# 1                               9.30142               86957.45836
# 2                               9.30142               86957.45836
# 3                               9.30142               86957.45836
# 4                               9.30142               86957.45836
#
#    Nb Logement Secondaire et Occasionnel  Nb Hotel  Capacité Hotel  \
# 0                                   32.0       0.0             0.0
# 1                                   71.0       0.0             0.0
# 2                                  135.0       2.0            52.0
# 3                                   14.0       2.0            17.0
# 4                                   13.0       0.0             0.0
#
#    Nb Camping  Capacité Camping  Taux Propriété  \
# 0         0.0               0.0              67
# 1         0.0               0.0              42
# 2         0.0               0.0              37
# 3         1.0              72.0              68
# 4         0.0               0.0              49
#
#    Dynamique Démographique INSEE  Capacité Fisc  Moyenne Revnus fiscaux  \
# 0                             -1            117                 11483.5
# 1                              0            110                 11483.5
# 2                            -55            250                 11483.5
# 3                             -3            127                 11483.5
# 4                              0            109                 11483.5
#
#    Nb Education, santé, action sociale  Nb Services personnels et domestiques  \
# 0                                  3.0                                    1.0
# 1                                  0.0                                    0.0
# 2                                113.0                                   41.0
# 3                                  5.0                                    2.0
# 4                                  0.0                                    0.0
#
#    Nb Santé, action sociale  Nb Industries des biens intermédiaires  \
# 0                       0.0                                    9364
# 1                       0.0                                    9364
# 2                     118.0                                    9364
# 3                       7.0                                    9364
# 4                       0.0                                    9364
#
#    Nb de Commerce  Nb de Services aux particuliers  \
# 0            9350                             3372
# 1            9350                             3372
# 2            9350                             3372
# 3            9350                             3372
# 4            9350                             3372
#
#    Nb institution de Education, santé, action sociale, administration  \
# 0                                              15105
# 1                                              15105
# 2                                              15105
# 3                                              15105
# 4                                              15105
#
#    PIB Régionnal  Score Croissance Entrepreneuriale   latitude  longitude  \
# 0         173681                            0.01585  46.153721   4.925850
# 1         173681                            0.00173  46.009606   5.428088
# 2         173681                            0.38471  45.961049   5.372275
# 3         173681                            0.02824  45.996164   4.911967
# 4         173681                            0.00000  45.749886   5.594585
#
#    Population en 2014 (princ)  Pop 0-14 ans en 2014 (princ)  \
# 0                       767.0                         161.0
# 1                       239.0                          54.0
# 2                     14022.0                        2778.0
# 3                      1627.0                         336.0
# 4                       109.0                          12.0
#
#    Pop 15-29 ans en 2014 (princ)  Pop 30-44 ans en 2014 (princ)  \
# 0                          102.0                          132.0
# 1                           28.0                           69.0
# 2                         2958.0                         2642.0
# 3                          251.0                          323.0
# 4                           16.0                           15.0
#
#    Pop 45-59 ans en 2014 (princ)  Pop 60-74 ans en 2014 (princ)  \
# 0                          189.0                          125.0
# 1                           36.0                           33.0
# 2                         2603.0                         1853.0
# 3                          376.0                          232.0
# 4                           29.0                           27.0
#
#    Pop 75-89 ans en 2014 (princ)  Pop 15 ans ou plus en 2014 (compl)  \
# 0                           53.0                               605.0
# 1                           17.0                               192.0
# 2                         1045.0                             11228.0
# 3                           99.0                              1337.0
# 4                           10.0                                89.0
#
#    Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)  \
# 0                                               15.0
# 1                                                0.0
# 2                                                3.0
# 3                                                5.0
# 4                                                0.0
#
#    Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)  \
# 0                                               20.0
# 1                                               20.0
# 2                                              334.0
# 3                                               60.0
# 4                                                0.0
#
#    Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)  \
# 0                                               75.0
# 1                                               15.0
# 2                                              743.0
# 3                                              106.0
# 4                                                5.0
#
#    Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)  \
# 0                                               95.0
# 1                                               25.0
# 2                                             1777.0
# 3                                              231.0
# 4                                               25.0
#
#    Pop 15 ans ou plus Employés en 2014 (compl)  \
# 0                                        100.0
# 1                                         39.0
# 2                                       1918.0
# 3                                        241.0
# 4                                         15.0
#
#    Pop 15 ans ou plus Ouvriers en 2014 (compl)  \
# 0                                        125.0
# 1                                         10.0
# 2                                       1818.0
# 3                                        231.0
# 4                                         15.0
#
#    Pop 15 ans ou plus Retraités  en 2014 (compl)  \
# 0                                          145.0
# 1                                           64.0
# 2                                         2878.0
# 3                                          312.0
# 4                                           25.0
#
#    Pop 15 ans ou plus Autres en 2014 (compl)  taux chômage(15-64 ans)  \
# 0                                       30.0                 8.776596
# 1                                       20.0                 8.130081
# 2                                     1757.0                15.859777
# 3                                      151.0                 7.875895
# 4                                        5.0                13.793103
#
#             SEG Croissance POP           Urbanité Ruralité  \
# 0  en croissance démographique  Com rurale < 2 000 m habts
# 1  en croissance démographique  Com rurale < 2 000 m habts
# 2  en croissance démographique            Com < 50 m habts
# 3  en croissance démographique  Com rurale < 2 000 m habts
# 4  en croissance démographique  Com rurale < 2 000 m habts
#
#                           Dynamique Démographique BV  \
# 0  1.Accroissement par excédent naturel et migrat...
# 1  1.Accroissement par excédent naturel et migrat...
# 2  1.Accroissement par excédent naturel et migrat...
# 3                                       Grande Ville
# 4            3.Accroissement par excédent migratoire
#
#                       Environnement Démographique        Fidélité  \
# 0   Bassin Industriel en croissance démographique  Pop Sédentaire
# 1  Bassin Résidentiel en croissance démographique  Pop Sédentaire
# 2  Bassin Résidentiel en croissance démographique      Pop Mobile
# 3       Bassin Urbain en croissance démographique      Pop Mobile
# 4  Bassin Résidentiel en croissance démographique  Pop Sédentaire
#
#      Seg Cap Fiscale         Seg Dyn Entre  \
# 0  Fiscalité moyenne      Faible dynamique
# 1  Fiscalité moyenne      Faible dynamique
# 2  Fiscalité moyenne  Dynamique Economique
# 3  Fiscalité moyenne     Moyenne dynamique
# 4  Fiscalité moyenne      Faible dynamique
#
#                                  DYN SetC  \
# 0            Faible Dynamique Serv et Com
# 1            Faible Dynamique Serv et Com
# 2  Bonne Dynamique Entreprise Serv et Com
# 3            Faible Dynamique Serv et Com
# 4            Faible Dynamique Serv et Com
#
#   Catégorie commune dans aire d'attraction des villes 2020  \
# 0                             Commune de la couronne
# 1                  Commune hors attraction des pôles
# 2                                     Commune-centre
# 3                             Commune de la couronne
# 4                             Commune de la couronne
#
#   Tranche détaillée d'aire d'attraction des villes 2020  \
# 0                  Aire de moins de 10 000 habitants
# 1                 Commune hors attraction des villes
# 2         Aire de 30 000 à moins de 50 000 habitants
# 3  Aire de 1 000 000 d’habitants ou plus (hors Pa...
# 4         Aire de 20 000 à moins de 30 000 habitants
#
#          Libellé degré de densité
# 0        Rural à habitat dispersé
# 1        Rural à habitat dispersé
# 2  Centres urbains intermédiaires
# 3                   Bourgs ruraux
# 4        Rural à habitat dispersé

# %%
# Select only the numerical columns
numeric_columns = X.select_dtypes(include=['int', 'float'])

# Get a list of the names of numerical columns
features_list = numeric_columns.columns

# Apply transformations only to the numerical columns
for c in features_list:
    # Square each element in the column
    X.loc[:, c + '_2'] = numeric_columns[c] ** 2
    
    # Cube each element in the column
    X.loc[:, c + '_3'] = numeric_columns[c] ** 3
    
    # Raise each element in the column to the power of 4
    X.loc[:, c + '_4'] = numeric_columns[c] ** 4
    
    # Calculate the inverse, checking for zero denominator
    X.loc[:, c + '_inverse'] = 1 / numeric_columns[c].replace(0, np.nan)
    
    # Calculate the inverse of the square, checking for zero denominator
    X.loc[:, c + '_inverse2'] = 1 / (numeric_columns[c] ** 2).replace(0, np.nan)

# Display the first few rows of the modified DataFrame
print(X.head())
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_2'] = colonnes_numeriques[c] ** 2
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_3'] = colonnes_numeriques[c] ** 3
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_4'] = colonnes_numeriques[c] ** 4
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse'] = 1 / colonnes_numeriques[c].replace(0, np.nan)
# C:\Users\alexa\AppData\Local\Temp\ipykernel_13552\2042631546.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.loc[:, c + '_inverse2'] = 1 / (colonnes_numeriques[c] ** 2).replace(0, np.nan)
# ...
# 1                                                0.0
# 2                                                9.0
# 3                                               25.0
# 4                                                0.0
#
#    Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)_3  \
# 0                                             3375.0
# 1                                                0.0
# 2                                               27.0
# 3                                              125.0
# 4                                                0.0
#
#    Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)_4  \
# 0                                            50625.0
# 1                                                0.0
# 2                                               81.0
# 3                                              625.0
# 4                                                0.0
#
#    Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)_inverse  \
# 0                                           0.066667
# 1                                                NaN
# 2                                           0.333333
# 3                                           0.200000
# 4                                                NaN
#
#    Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)_inverse2  \
# 0                                           0.004444
# 1                                                NaN
# 2                                           0.111111
# 3                                           0.040000
# 4                                                NaN
#
#    Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_2  \
# 0                                              400.0
# 1                                              400.0
# 2                                           111556.0
# 3                                             3600.0
# 4                                                0.0
#
#    Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_3  \
# 0                                             8000.0
# 1                                             8000.0
# 2                                         37259704.0
# 3                                           216000.0
# 4                                                0.0
#
#    Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_4  \
# 0                                       1.600000e+05
# 1                                       1.600000e+05
# 2                                       1.244474e+10
# 3                                       1.296000e+07
# 4                                       0.000000e+00
#
#    Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_inverse  \
# 0                                           0.050000
# 1                                           0.050000
# 2                                           0.002994
# 3                                           0.016667
# 4                                                NaN
#
#    Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_inverse2  \
# 0                                           0.002500
# 1                                           0.002500
# 2                                           0.000009
# 3                                           0.000278
# 4                                                NaN
#
#    Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_2  \
# 0                                             5625.0
# 1                                              225.0
# 2                                           552049.0
# 3                                            11236.0
# 4                                               25.0
#
#    Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_3  \
# 0                                           421875.0
# 1                                             3375.0
# 2                                        410172407.0
# 3                                          1191016.0
# 4                                              125.0
#
#    Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_4  \
# 0                                       3.164062e+07
# 1                                       5.062500e+04
# 2                                       3.047581e+11
# 3                                       1.262477e+08
# 4                                       6.250000e+02
#
#    Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_inverse  \
# 0                                           0.013333
# 1                                           0.066667
# 2                                           0.001346
# 3                                           0.009434
# 4                                           0.200000
#
#    Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_inverse2  \
# 0                                           0.000178
# 1                                           0.004444
# 2                                           0.000002
# 3                                           0.000089
# 4                                           0.040000
#
#    Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_2  \
# 0                                             9025.0
# 1                                              625.0
# 2                                          3157729.0
# 3                                            53361.0
# 4                                              625.0
#
#    Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_3  \
# 0                                       8.573750e+05
# 1                                       1.562500e+04
# 2                                       5.611284e+09
# 3                                       1.232639e+07
# 4                                       1.562500e+04
#
#    Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_4  \
# 0                                       8.145062e+07
# 1                                       3.906250e+05
# 2                                       9.971252e+12
# 3                                       2.847396e+09
# 4                                       3.906250e+05
#
#    Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_inverse  \
# 0                                           0.010526
# 1                                           0.040000
# 2                                           0.000563
# 3                                           0.004329
# 4                                           0.040000
#
#    Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_inverse2  \
# 0                                       1.108033e-04
# 1                                       1.600000e-03
# 2                                       3.166833e-07
# 3                                       1.874028e-05
# 4                                       1.600000e-03
#
#    Pop 15 ans ou plus Employés en 2014 (compl)_2  \
# 0                                        10000.0
# 1                                         1521.0
# 2                                      3678724.0
# 3                                        58081.0
# 4                                          225.0
#
#    Pop 15 ans ou plus Employés en 2014 (compl)_3  \
# 0                                   1.000000e+06
# 1                                   5.931900e+04
# 2                                   7.055793e+09
# 3                                   1.399752e+07
# 4                                   3.375000e+03
#
#    Pop 15 ans ou plus Employés en 2014 (compl)_4  \
# 0                                   1.000000e+08
# 1                                   2.313441e+06
# 2                                   1.353301e+13
# 3                                   3.373403e+09
# 4                                   5.062500e+04
#
#    Pop 15 ans ou plus Employés en 2014 (compl)_inverse  \
# 0                                           0.010000
# 1                                           0.025641
# 2                                           0.000521
# 3                                           0.004149
# 4                                           0.066667
#
#    Pop 15 ans ou plus Employés en 2014 (compl)_inverse2  \
# 0                                       1.000000e-04
# 1                                       6.574622e-04
# 2                                       2.718334e-07
# 3                                       1.721733e-05
# 4                                       4.444444e-03
#
#    Pop 15 ans ou plus Ouvriers en 2014 (compl)_2  \
# 0                                        15625.0
# 1                                          100.0
# 2                                      3305124.0
# 3                                        53361.0
# 4                                          225.0
#
#    Pop 15 ans ou plus Ouvriers en 2014 (compl)_3  \
# 0                                   1.953125e+06
# 1                                   1.000000e+03
# 2                                   6.008715e+09
# 3                                   1.232639e+07
# 4                                   3.375000e+03
#
#    Pop 15 ans ou plus Ouvriers en 2014 (compl)_4  \
# 0                                   2.441406e+08
# 1                                   1.000000e+04
# 2                                   1.092384e+13
# 3                                   2.847396e+09
# 4                                   5.062500e+04
#
#    Pop 15 ans ou plus Ouvriers en 2014 (compl)_inverse  \
# 0                                           0.008000
# 1                                           0.100000
# 2                                           0.000550
# 3                                           0.004329
# 4                                           0.066667
#
#    Pop 15 ans ou plus Ouvriers en 2014 (compl)_inverse2  \
# 0                                       6.400000e-05
# 1                                       1.000000e-02
# 2                                       3.025605e-07
# 3                                       1.874028e-05
# 4                                       4.444444e-03
#
#    Pop 15 ans ou plus Retraités  en 2014 (compl)_2  \
# 0                                          21025.0
# 1                                           4096.0
# 2                                        8282884.0
# 3                                          97344.0
# 4                                            625.0
#
#    Pop 15 ans ou plus Retraités  en 2014 (compl)_3  \
# 0                                     3.048625e+06
# 1                                     2.621440e+05
# 2                                     2.383814e+10
# 3                                     3.037133e+07
# 4                                     1.562500e+04
#
#    Pop 15 ans ou plus Retraités  en 2014 (compl)_4  \
# 0                                     4.420506e+08
# 1                                     1.677722e+07
# 2                                     6.860617e+13
# 3                                     9.475854e+09
# 4                                     3.906250e+05
#
#    Pop 15 ans ou plus Retraités  en 2014 (compl)_inverse  \
# 0                                           0.006897
# 1                                           0.015625
# 2                                           0.000347
# 3                                           0.003205
# 4                                           0.040000
#
#    Pop 15 ans ou plus Retraités  en 2014 (compl)_inverse2  \
# 0                                       4.756243e-05
# 1                                       2.441406e-04
# 2                                       1.207309e-07
# 3                                       1.027285e-05
# 4                                       1.600000e-03
#
#    Pop 15 ans ou plus Autres en 2014 (compl)_2  \
# 0                                        900.0
# 1                                        400.0
# 2                                    3087049.0
# 3                                      22801.0
# 4                                         25.0
#
#    Pop 15 ans ou plus Autres en 2014 (compl)_3  \
# 0                                 2.700000e+04
# 1                                 8.000000e+03
# 2                                 5.423945e+09
# 3                                 3.442951e+06
# 4                                 1.250000e+02
#
#    Pop 15 ans ou plus Autres en 2014 (compl)_4  \
# 0                                 8.100000e+05
# 1                                 1.600000e+05
# 2                                 9.529872e+12
# 3                                 5.198856e+08
# 4                                 6.250000e+02
#
#    Pop 15 ans ou plus Autres en 2014 (compl)_inverse  \
# 0                                           0.033333
# 1                                           0.050000
# 2                                           0.000569
# 3                                           0.006623
# 4                                           0.200000
#
#    Pop 15 ans ou plus Autres en 2014 (compl)_inverse2  \
# 0                                       1.111111e-03
# 1                                       2.500000e-03
# 2                                       3.239340e-07
# 3                                       4.385773e-05
# 4                                       4.000000e-02
#
#    taux chômage(15-64 ans)_2  taux chômage(15-64 ans)_3  \
# 0                  77.028633                 676.049171
# 1                  66.098222                 537.383918
# 2                 251.532526                3989.249776
# 3                  62.029722                 488.539576
# 4                 190.249703                2624.133831
#
#    taux chômage(15-64 ans)_4  taux chômage(15-64 ans)_inverse  \
# 0                5933.410281                         0.113939
# 1                4368.974946                         0.123000
# 2               63268.611824                         0.063053
# 3                3847.686394                         0.126970
# 4               36194.949391                         0.072500
#
#    taux chômage(15-64 ans)_inverse2
# 0                          0.012982
# 1                          0.015129
# 2                          0.003976
# 3                          0.016121
# 4                          0.005256

# %%
#Train-test splitting

print("Dividing into train and test sets...")
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print("...Done.")
print()
# Out:
# Dividing into train and test sets...
# ...Done.

# %%
# Automatically detect names of numeric/categorical columns
numeric_features = []
categorical_features = []
for i, t in X.dtypes.items():
    if ('float' in str(t)) or ('int' in str(t)):
        numeric_features.append(i)
    else:
        categorical_features.append(i)
print('Found numeric features ', numeric_features)
print('Found categorical features ', categorical_features)
# Out:
# Found numeric features  ['Dynamique Entrepreneuriale', 'Dynamique Entrepreneuriale Service et Commerce', 'Synergie Médicale COMMUNE', 'Nb Omnipraticiens BV', 'Nb Infirmiers Libéraux BV', 'Nb dentistes Libéraux BV', 'Nb pharmaciens Libéraux BV', 'Densité Médicale BV', 'Score équipement de santé BV', 'Indice Démographique', 'Nb Ménages', 'Nb Résidences Principales', 'Nb propriétaire', 'Nb Logement', 'Nb Résidences Secondaires', 'Nb Log Vacants', 'Nb Occupants Résidence Principale', 'Nb Entreprises Secteur Services', 'Nb Entreprises Secteur Commerce', 'Nb Entreprises Secteur Construction', 'Nb Entreprises Secteur Industrie', 'Nb Création Enteprises', 'Nb Création Industrielles', 'Nb Création Construction', 'Nb Création Commerces', 'Nb Création Services', 'Moyenne Revenus Fiscaux Départementaux', 'Moyenne Revenus Fiscaux Régionaux', 'Dep Moyenne Salaires Horaires', 'Dep Moyenne Salaires Cadre Horaires', 'Dep Moyenne Salaires Prof Intermédiaire Horaires', 'Dep Moyenne Salaires Employé Horaires', 'Dep Moyenne Salaires Ouvrié Horaires', 'Reg Moyenne Salaires Horaires', 'Reg Moyenne Salaires Cadre Horaires', 'Reg Moyenne Salaires Prof Intermédiaire Horaires', 'Reg Moyenne Salaires Employé Horaires', 'Reg Moyenne Salaires Ouvrié Horaires', 'Valeur ajoutée régionale', 'Nb Logement Secondaire et Occasionnel', 'Nb Hotel', 'Capacité Hotel', 'Nb Camping', 'Capacité Camping', 'Taux Propriété', 'Dynamique Démographique INSEE', 'Capacité Fisc', 'Moyenne Revnus fiscaux', 'Nb Education, santé, action sociale', 'Nb Services personnels et domestiques', 'Nb Santé, action sociale', 'Nb Industries des biens intermédiaires', 'Nb de Commerce', 'Nb de Services aux particuliers', 'Nb institution de Education, santé, action sociale, administration', 'PIB Régionnal', 'Score Croissance Entrepreneuriale', 'latitude', 'longitude', 'Population en 2014 (princ)', 'Pop 0-14 ans en 2014 (princ)', 'Pop 15-29 ans en 2014 (princ)', 'Pop 30-44 ans en 2014 (princ)', 'Pop 45-59 ans en 2014 (princ)', 'Pop 60-74 ans en 2014 (princ)', 'Pop 75-89 ans en 2014 (princ)', 'Pop 15 ans ou plus en 2014 (compl)', 'Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)', 'Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)', 'Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)', 'Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)', 'Pop 15 ans ou plus Employés en 2014 (compl)', 'Pop 15 ans ou plus Ouvriers en 2014 (compl)', 'Pop 15 ans ou plus Retraités  en 2014 (compl)', 'Pop 15 ans ou plus Autres en 2014 (compl)', 'taux chômage(15-64 ans)', 'Dynamique Entrepreneuriale_2', 'Dynamique Entrepreneuriale_3', 'Dynamique Entrepreneuriale_4', 'Dynamique Entrepreneuriale_inverse', 'Dynamique Entrepreneuriale_inverse2', 'Dynamique Entrepreneuriale Service et Commerce_2', 'Dynamique Entrepreneuriale Service et Commerce_3', 'Dynamique Entrepreneuriale Service et Commerce_4', 'Dynamique Entrepreneuriale Service et Commerce_inverse', 'Dynamique Entrepreneuriale Service et Commerce_inverse2', 'Synergie Médicale COMMUNE_2', 'Synergie Médicale COMMUNE_3', 'Synergie Médicale COMMUNE_4', 'Synergie Médicale COMMUNE_inverse', 'Synergie Médicale COMMUNE_inverse2', 'Nb Omnipraticiens BV_2', 'Nb Omnipraticiens BV_3', 'Nb Omnipraticiens BV_4', 'Nb Omnipraticiens BV_inverse', 'Nb Omnipraticiens BV_inverse2', 'Nb Infirmiers Libéraux BV_2', 'Nb Infirmiers Libéraux BV_3', 'Nb Infirmiers Libéraux BV_4', 'Nb Infirmiers Libéraux BV_inverse', 'Nb Infirmiers Libéraux BV_inverse2', 'Nb dentistes Libéraux BV_2', 'Nb dentistes Libéraux BV_3', 'Nb dentistes Libéraux BV_4', 'Nb dentistes Libéraux BV_inverse', 'Nb dentistes Libéraux BV_inverse2', 'Nb pharmaciens Libéraux BV_2', 'Nb pharmaciens Libéraux BV_3', 'Nb pharmaciens Libéraux BV_4', 'Nb pharmaciens Libéraux BV_inverse', 'Nb pharmaciens Libéraux BV_inverse2', 'Densité Médicale BV_2', 'Densité Médicale BV_3', 'Densité Médicale BV_4', 'Densité Médicale BV_inverse', 'Densité Médicale BV_inverse2', 'Score équipement de santé BV_2', 'Sc ...
# Found categorical features  ['SEG Croissance POP', 'Urbanité Ruralité', 'Dynamique Démographique BV', 'Environnement Démographique', 'Fidélité', 'Seg Cap Fiscale', 'Seg Dyn Entre', 'DYN SetC', "Catégorie commune dans aire d'attraction des villes 2020", "Tranche détaillée d'aire d'attraction des villes 2020", 'Libellé degré de densité']

# %%
#Multiple Transformations preprocessing

# Create pipeline for numeric features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')), # missing values will be replaced by columns' mean
    ('scaler', StandardScaler())
])

# Create pipeline for categorical features
categorical_transformer = Pipeline(
    steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')), # missing values will be replaced by most frequent value
    ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore')) # first column will be dropped to avoid creating correlations between features
    ])

# Use ColumnTransformer to make a preprocessor object that describes all the treatments to be done
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# %%
# Preprocessings on train set
print("Performing preprocessings on train set...")
print(X_train.head())
X_train = preprocessor.fit_transform(X_train)
print('...Done.')
print(X_train[0:5,:])
print()

# Preprocessings on test set
print("Performing preprocessings on test set...")
print(X_test.head())
X_test = preprocessor.transform(X_test) # Don't fit again !!
print('...Done.')
print(X_test[0:5,:])
print()
# Out:
# Performing preprocessings on train set...
#        Dynamique Entrepreneuriale  \
# 19078                        41.0
# 7714                         40.0
# 3753                         11.0
# 10173                        63.0
# 26517                        70.0
#
#        Dynamique Entrepreneuriale Service et Commerce  \
# 19078                                            16.0
# 7714                                             14.0
# 3753                                              1.0
# 10173                                            10.0
# 26517                                            55.0
#
#        Synergie Médicale COMMUNE  Nb Omnipraticiens BV  \
# 19078                         77                    12
# 7714                          46                    10
# 3753                          33                     8
# 10173                         97                     4
# 26517                         99                    12
#
#        Nb Infirmiers Libéraux BV  Nb dentistes Libéraux BV  \
# 19078                         12                         6
# 7714                           8                         5
# 3753                           4                         3
# 10173                         13                         5
# 26517                         12                         6
#
#        Nb pharmaciens Libéraux BV  Densité Médicale BV  \
# 19078                           6             1.000000
# 7714                            5             0.070734
# 3753                            3             0.058666
# 10173                           5             0.106269
# 26517                           6             1.000000
#
#        Score équipement de santé BV  Indice Démographique  Nb Ménages  \
# 19078                             1              21.58066         132
# 7714                              3              30.60309         182
# 3753                              2               2.43849          18
# 10173                             1              27.79882         177
# 26517                             1             141.37164         841
#
#        Nb Résidences Principales  Nb propriétaire  Nb Logement  \
# 19078                        132               98          152
# 7714                         182              136          209
# 3753                          18               14           23
# 10173                        177              135          237
# 26517                        840              590          875
#
#        Nb Résidences Secondaires  Nb Log Vacants  \
# 19078                          2              18
# 7714                          12              15
# 3753                           4               1
# 10173                         51               9
# 26517                          7              28
#
#        Nb Occupants Résidence Principale  Nb Entreprises Secteur Services  \
# 19078                                354                              6.0
# 7714                                 483                              6.0
# 3753                                  40                              1.0
# 10173                                456                              5.0
# 26517                               2310                             30.0
#
#        Nb Entreprises Secteur Commerce  Nb Entreprises Secteur Construction  \
# 19078                              7.0                                  6.0
# 7714                               5.0                                  9.0
# 3753                               0.0                                  1.0
# 10173                              3.0                                  4.0
# 26517                             14.0                                  2.0
#
#        Nb Entreprises Secteur Industrie  Nb Création Enteprises  \
# 19078                               3.0                     1.0
# 7714                                5.0                     1.0
# 3753                                0.0                     0.0
# 10173                               7.0                     1.0
# 26517                              15.0                     2.0
#
#        Nb Création Industrielles  Nb Création Construction  \
# 19078                        0.0                       1.0
# 7714                         0.0                       1.0
# 3753                         0.0                       0.0
# 10173                        0.0                       0.0
# 26517                        0.0                       0.0
#
#        Nb Création Commerces  Nb Création Services  \
# 19078                    0.0                   0.0
# 7714                     0.0                   0.0
# 3753                     0.0                   0.0
# 10173                    0.0                   1.0
# 26517                    1.0                   1.0
#
#        Moyenne Revenus Fiscaux Départementaux  \
# 19078                                    9860
# 7714                                    14584
# 3753                                     9364
# 10173                                    6688
# 26517                                    8966
#
#        Moyenne Revenus Fiscaux Régionaux  Dep Moyenne Salaires Horaires  \
# 19078                              10566                      10.114286
# 7714                               10836                      11.059259
# 3753                               10046                      10.480952
# 10173                              10458                      10.955263
# 26517                               9097                      10.708276
#
#        Dep Moyenne Salaires Cadre Horaires  \
# 19078                            20.467857
# 7714                             20.918519
# 3753                             21.352381
# 10173                            21.181579
# 26517                            20.540690
#
#        Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# 19078                                         12.050000
# 7714                                          12.511111
# 3753                                          12.566667
# 10173                                         12.360526
# 26517                                         12.437931
#
#        Dep Moyenne Salaires Employé Horaires  \
# 19078                               8.342857
# 7714                                8.770370
# 3753                                8.523810
# 10173                               8.581579
# 26517                               8.556552
#
#        Dep Moyenne Salaires Ouvrié Horaires  Reg Moyenne Salaires Horaires  \
# 19078                              8.557143                      10.992609
# 7714                               9.174074                      10.653774
# 3753                               8.585714                      10.652439
# 10173                              8.860526                      11.873022
# 26517                              9.168966                      11.020690
#
#        Reg Moyenne Salaires Cadre Horaires  \
# 19078                            21.248696
# 7714                             21.221698
# 3753                             20.931707
# 10173                            21.787830
# 26517                            20.509549
#
#        Reg Moyenne Salaires Prof Intermédiaire Horaires  \
# 19078                                         12.435217
# 7714                                          12.430189
# 3753                                          12.489024
# 10173                                         12.704057
# 26517                                         12.444562
#
#        Reg Moyenne Salaires Employé Horaires  \
# 19078                               8.601739
# 7714                                8.555660
# 3753                                8.663415
# 10173                               8.783164
# 26517                               8.645358
#
#        Reg Moyenne Salaires Ouvrié Horaires  Valeur ajoutée régionale  \
# 19078                              8.915652               38930.86531
# 7714                               8.976415               22655.68901
# 3753                               9.082927               19749.43799
# 10173                              9.301420               86957.45836
# 26517                              9.179576               49305.17136
#
#        Nb Logement Secondaire et Occasionnel  Nb Hotel  Capacité Hotel  \
# 19078                                    2.0       0.0             0.0
# 7714                                    12.0       0.0             0.0
# 3753                                     4.0       0.0             0.0
# 10173                                   51.0       0.0             0.0
# 26517                                    7.0       1.0             8.0
#
#        Nb Camping  Capacité Camping  Taux Propriété  \
# 19078         0.0               0.0              64
# 7714          0.0               0.0              65
# 3753          0.0               0.0              60
# 10173         0.0               0.0              56
# 26517         0.0               0.0              67
#
#        Dynamique Démographique INSEE  Capacité Fisc  Moyenne Revnus fiscaux  \
# 19078                              0             82                 10213.0
# 7714                              -1             86                 12710.0
# 3753                               0             66                  9705.0
# 10173                              0            101                  8573.0
# 26517                             -5            101                  9031.5
#
#        Nb Education, santé, action sociale  \
# 19078                                  1.0
# 7714                                   1.0
# 3753                                   0.0
# 10173                                  0.0
# 26517                                 10.0
#
#        Nb Services personnels et domestiques  Nb Santé, action sociale  \
# 19078                                    0.0                       2.0
# 7714                                     0.0                       2.0
# 3753                                     0.0                       0.0
# 10173                                    0.0                       0.0
# 26517                                    0.0                      11.0
#
#        Nb Industries des biens intermédiaires  Nb de Commerce  \
# 19078                                    2051            4876
# 7714                                     2576            2517
# 3753                                     2230            2004
# 10173                                    9364            9350
# 26517                                    6310            6056
#
#        Nb de Services aux particuliers  \
# 19078                             1552
# 7714                               873
# 3753                               542
# 10173                             3372
# 26517                             1376
#
#        Nb institution de Education, santé, action sociale, administration  \
# 19078                                               8683
# 7714                                                4560
# 3753                                                3832
# 10173                                              15105
# 26517                                              10702
#
#        PIB Régionnal  Score Croissance Entrepreneuriale   latitude  longitude  \
# 19078          79920                            0.00173  44.131503   0.755953
# 7714           40484                            0.00173  47.488104   5.217836
# 3753           35310                            0.00000  48.462193   4.554498
# 10173         173681                            0.00173  45.192137   5.039200
# 26517          90841                            0.01239  50.334843   3.047671
#
#        Population en 2014 (princ)  Pop 0-14 ans en 2014 (princ)  \
# 19078                       392.0                          66.0
# 7714                        526.0                         111.0
# 3753                         42.0                           7.0
# 10173                       587.0                         124.0
# 26517                      2329.0                         507.0
#
#        Pop 15-29 ans en 2014 (princ)  Pop 30-44 ans en 2014 (princ)  \
# 19078                           62.0                           75.0
# 7714                            84.0                          113.0
# 3753                             9.0                            5.0
# 10173                           66.0                          124.0
# 26517                          385.0                          480.0
#
#        Pop 45-59 ans en 2014 (princ)  Pop 60-74 ans en 2014 (princ)  \
# 19078                           78.0                           78.0
# 7714                           100.0                           74.0
# 3753                            10.0                            8.0
# 10173                          124.0                          111.0
# 26517                          419.0                          316.0
#
#        Pop 75-89 ans en 2014 (princ)  Pop 15 ans ou plus en 2014 (compl)  \
# 19078                           26.0                               323.0
# 7714                            37.0                               411.0
# 3753                             3.0                                45.0
# 10173                           35.0                               452.0
# 26517                          196.0                              1808.0
#
#        Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)  \
# 19078                                               10.0
# 7714                                                20.0
# 3753                                                 0.0
# 10173                                               20.0
# 26517                                                0.0
#
#        Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)  \
# 19078                                                5.0
# 7714                                                16.0
# 3753                                                 0.0
# 10173                                               32.0
# 26517                                               30.0
#
#        Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)  \
# 19078                                                5.0
# 7714                                                36.0
# 3753                                                 0.0
# 10173                                               16.0
# 26517                                               56.0
#
#        Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)  \
# 19078                                               63.0
# 7714                                                48.0
# 3753                                                 0.0
# 10173                                               52.0
# 26517                                              279.0
#
#        Pop 15 ans ou plus Employés en 2014 (compl)  \
# 19078                                         39.0
# 7714                                          44.0
# 3753                                           5.0
# 10173                                         77.0
# 26517                                        319.0
#
#        Pop 15 ans ou plus Ouvriers en 2014 (compl)  \
# 19078                                         53.0
# 7714                                          85.0
# 3753                                          25.0
# 10173                                         65.0
# 26517                                        277.0
#
#        Pop 15 ans ou plus Retraités  en 2014 (compl)  \
# 19078                                          111.0
# 7714                                           117.0
# 3753                                            15.0
# 10173                                          157.0
# 26517                                          481.0
#
#        Pop 15 ans ou plus Autres en 2014 (compl)  taux chômage(15-64 ans)  \
# 19078                                       39.0                 9.239130
# 7714                                        44.0                 8.661417
# 3753                                         0.0                22.727273
# 10173                                       32.0                11.027364
# 26517                                      367.0                13.262123
#
#                 SEG Croissance POP           Urbanité Ruralité  \
# 19078  en croissance démographique  Com rurale < 2 000 m habts
# 7714   en croissance démographique  Com rurale < 2 000 m habts
# 3753   en croissance démographique  Com rurale < 2 000 m habts
# 10173  en croissance démographique  Com rurale < 2 000 m habts
# 26517  en croissance démographique           Com > 200 m habts
#
#                               Dynamique Démographique BV  \
# 19078                                       Grande Ville
# 7714                2.Accroissement par excédent naturel
# 3753          4.Déclin par déficit naturel et migratoire
# 10173  1.Accroissement par excédent naturel et migrat...
# 26517                                       Grande Ville
#
#                           Environnement Démographique        Fidélité  \
# 19078       Bassin Urbain en croissance démographique  Pop Sédentaire
# 7714    Bassin Industriel en croissance démographique  Pop Sédentaire
# 3753   Bassin Résidentiel en croissance démographique  Pop Sédentaire
# 10173   Bassin diversifié en croissance démographique  Pop Sédentaire
# 26517       Bassin Urbain en croissance démographique  Pop Sédentaire
#
#          Seg Cap Fiscale     Seg Dyn Entre                      DYN SetC  \
# 19078  Fiscalité moyenne  Faible dynamique  Faible Dynamique Serv et Com
# 7714   Fiscalité moyenne  Faible dynamique  Faible Dynamique Serv et Com
# 3753   Fiscalité moyenne  Faible dynamique  Faible Dynamique Serv et Com
# 10173  Fiscalité moyenne  Faible dynamique  Faible Dynamique Serv et Com
# 26517   Fiscalité faible  Faible dynamique  Faible Dynamique Serv et Com
#
#       Catégorie commune dans aire d'attraction des villes 2020  \
# 19078                             Commune de la couronne
# 7714                              Commune de la couronne
# 3753                              Commune de la couronne
# 10173                             Commune de la couronne
# 26517                             Commune de la couronne
#
#       Tranche détaillée d'aire d'attraction des villes 2020  \
# 19078       Aire de 100 000 à moins de 125 000 habitants
# 7714        Aire de 400 000 à moins de 500 000 habitants
# 3753                   Aire de moins de 10 000 habitants
# 10173         Aire de 50 000 à moins de 75 000 habitants
# 26517       Aire de 150 000 à moins de 200 000 habitants
#
#             Libellé degré de densité  Dynamique Entrepreneuriale_2  \
# 19078       Rural à habitat dispersé                        1681.0
# 7714        Rural à habitat dispersé                        1600.0
# 3753   Rural à habitat très dispersé                         121.0
# 10173  Rural à habitat très dispersé                        3969.0
# 26517             Ceintures urbaines                        4900.0
#
#        Dynamique Entrepreneuriale_3  Dynamique Entrepreneuriale_4  \
# 19078                       68921.0                     2825761.0
# 7714                        64000.0                     2560000.0
# 3753                         1331.0                       14641.0
# 10173                      250047.0                    15752961.0
# 26517                      343000.0                    24010000.0
#
#        Dynamique Entrepreneuriale_inverse  \
# 19078                            0.024390
# 7714                             0.025000
# 3753                             0.090909
# 10173                            0.015873
# 26517                            0.014286
#
#        Dynamique Entrepreneuriale_inverse2  \
# 19078                             0.000595
# 7714                              0.000625
# 3753                              0.008264
# 10173                             0.000252
# 26517                             0.000204
#
#        Dynamique Entrepreneuriale Service et Commerce_2  \
# 19078                                             256.0
# 7714                                              196.0
# 3753                                                1.0
# 10173                                             100.0
# 26517                                            3025.0
#
#        Dynamique Entrepreneuriale Service et Commerce_3  \
# 19078                                            4096.0
# 7714                                             2744.0
# 3753                                                1.0
# 10173                                            1000.0
# 26517                                          166375.0
#
#        Dynamique Entrepreneuriale Service et Commerce_4  \
# 19078                                           65536.0
# 7714                                            38416.0
# 3753                                                1.0
# 10173                                           10000.0
# 26517                                         9150625.0
#
#        Dynamique Entrepreneuriale Service et Commerce_inverse  \
# 19078                                           0.062500
# 7714                                            0.071429
# 3753                                            1.000000
# 10173                                           0.100000
# 26517                                           0.018182
#
#        Dynamique Entrepreneuriale Service et Commerce_inverse2  \
# 19078                                           0.003906
# 7714                                            0.005102
# 3753                                            1.000000
# 10173                                           0.010000
# 26517                                           0.000331
#
#        Synergie Médicale COMMUNE_2  Synergie Médicale COMMUNE_3  \
# 19078                         5929                       456533
# 7714                          2116                        97336
# 3753                          1089                        35937
# 10173                         9409                       912673
# 26517                         9801                       970299
#
#        Synergie Médicale COMMUNE_4  Synergie Médicale COMMUNE_inverse  \
# 19078                     35153041                           0.012987
# 7714                       4477456                           0.021739
# 3753                       1185921                           0.030303
# 10173                     88529281                           0.010309
# 26517                     96059601                           0.010101
#
#        Synergie Médicale COMMUNE_inverse2  Nb Omnipraticiens BV_2  \
# 19078                            0.000169                     144
# 7714                             0.000473                     100
# 3753                             0.000918                      64
# 10173                            0.000106                      16
# 26517                            0.000102                     144
#
#        Nb Omnipraticiens BV_3  Nb Omnipraticiens BV_4  \
# 19078                    1728                   20736
# 7714                     1000                   10000
# 3753                      512                    4096
# 10173                      64                     256
# 26517                    1728                   20736
#
#        Nb Omnipraticiens BV_inverse  Nb Omnipraticiens BV_inverse2  \
# 19078                      0.083333                       0.006944
# 7714                       0.100000                       0.010000
# 3753                       0.125000                       0.015625
# 10173                      0.250000                       0.062500
# 26517                      0.083333                       0.006944
#
#        Nb Infirmiers Libéraux BV_2  Nb Infirmiers Libéraux BV_3  \
# 19078                          144                         1728
# 7714                            64                          512
# 3753                            16                           64
# 10173                          169                         2197
# 26517                          144                         1728
#
#        Nb Infirmiers Libéraux BV_4  Nb Infirmiers Libéraux BV_inverse  \
# 19078                        20736                           0.083333
# 7714                          4096                           0.125000
# 3753                           256                           0.250000
# 10173                        28561                           0.076923
# 26517                        20736                           0.083333
#
#        Nb Infirmiers Libéraux BV_inverse2  Nb dentistes Libéraux BV_2  \
# 19078                            0.006944                          36
# 7714                             0.015625                          25
# 3753                             0.062500                           9
# 10173                            0.005917                          25
# 26517                            0.006944                          36
#
#        Nb dentistes Libéraux BV_3  Nb dentistes Libéraux BV_4  \
# 19078                         216                        1296
# 7714                          125                         625
# 3753                           27                          81
# 10173                         125                         625
# 26517                         216                        1296
#
#        Nb dentistes Libéraux BV_inverse  Nb dentistes Libéraux BV_inverse2  \
# 19078                          0.166667                           0.027778
# 7714                           0.200000                           0.040000
# 3753                           0.333333                           0.111111
# 10173                          0.200000                           0.040000
# 26517                          0.166667                           0.027778
#
#        Nb pharmaciens Libéraux BV_2  Nb pharmaciens Libéraux BV_3  \
# 19078                            36                           216
# 7714                             25                           125
# 3753                              9                            27
# 10173                            25                           125
# 26517                            36                           216
#
#        Nb pharmaciens Libéraux BV_4  Nb pharmaciens Libéraux BV_inverse  \
# 19078                          1296                            0.166667
# 7714                            625                            0.200000
# 3753                             81                            0.333333
# 10173                           625                            0.200000
# 26517                          1296                            0.166667
#
#        Nb pharmaciens Libéraux BV_inverse2  Densité Médicale BV_2  \
# 19078                             0.027778               1.000000
# 7714                              0.040000               0.005003
# 3753                              0.111111               0.003442
# 10173                             0.040000               0.011293
# 26517                             0.027778               1.000000
#
#        Densité Médicale BV_3  Densité Médicale BV_4  \
# 19078               1.000000               1.000000
# 7714                0.000354               0.000025
# 3753                0.000202               0.000012
# 10173               0.001200               0.000128
# 26517               1.000000               1.000000
#
#        Densité Médicale BV_inverse  Densité Médicale BV_inverse2  \
# 19078                     1.000000                      1.000000
# 7714                     14.137441                    199.867233
# 3753                     17.045714                    290.556373
# 10173                     9.410095                     88.549881
# 26517                     1.000000                      1.000000
#
#        Score équipement de santé BV_2  Score équipement de santé BV_3  \
# 19078                               1                               1
# 7714                                9                              27
# 3753                                4                               8
# 10173                               1                               1
# 26517                               1                               1
#
#        Score équipement de santé BV_4  Score équipement de santé BV_inverse  \
# 19078                               1                              1.000000
# 7714                               81                              0.333333
# 3753                               16                              0.500000
# 10173                               1                              1.000000
# 26517                               1                              1.000000
#
#        Score équipement de santé BV_inverse2  Indice Démographique_2  \
# 19078                               1.000000              465.724886
# 7714                                0.111111              936.549118
# 3753                                0.250000                5.946233
# 10173                               1.000000              772.774393
# 26517                               1.000000            19985.940596
#
#        Indice Démographique_3  Indice Démographique_4  \
# 19078            1.005065e+04            2.168997e+05
# 7714             2.866130e+04            8.771242e+05
# 3753             1.449983e+01            3.535769e+01
# 10173            2.148222e+04            5.971803e+05
# 26517            2.825445e+06            3.994378e+08
#
#        Indice Démographique_inverse  Indice Démographique_inverse2  \
# 19078                      0.046338                       0.002147
# 7714                       0.032676                       0.001068
# 3753                       0.410090                       0.168174
# 10173                      0.035973                       0.001294
# 26517                      0.007074                       0.000050
#
#        Nb Ménages_2  Nb Ménages_3  Nb Ménages_4  Nb Ménages_inverse  \
# 19078         17424       2299968     303595776            0.007576
# 7714          33124       6028568    1097199376            0.005495
# 3753            324          5832        104976            0.055556
# 10173         31329       5545233     981506241            0.005650
# 26517        707281     594823321  500246412961            0.001189
#
#        Nb Ménages_inverse2  Nb Résidences Principales_2  \
# 19078             0.000057                        17424
# 7714              0.000030                        33124
# 3753              0.003086                          324
# 10173             0.000032                        31329
# 26517             0.000001                       705600
#
#        Nb Résidences Principales_3  Nb Résidences Principales_4  \
# 19078                      2299968                    303595776
# 7714                       6028568                   1097199376
# 3753                          5832                       104976
# 10173                      5545233                    981506241
# 26517                    592704000                 497871360000
#
#        Nb Résidences Principales_inverse  Nb Résidences Principales_inverse2  \
# 19078                           0.007576                            0.000057
# 7714                            0.005495                            0.000030
# 3753                            0.055556                            0.003086
# 10173                           0.005650                            0.000032
# 26517                           0.001190                            0.000001
#
#        Nb propriétaire_2  Nb propriétaire_3  Nb propriétaire_4  \
# 19078               9604             941192           92236816
# 7714               18496            2515456          342102016
# 3753                 196               2744              38416
# 10173              18225            2460375          332150625
# 26517             348100          205379000       121173610000
#
#        Nb propriétaire_inverse  Nb propriétaire_inverse2  Nb Logement_2  \
# 19078                 0.010204                  0.000104          23104
# 7714                  0.007353                  0.000054          43681
# 3753                  0.071429                  0.005102            529
# 10173                 0.007407                  0.000055          56169
# 26517                 0.001695                  0.000003         765625
#
#        Nb Logement_3  Nb Logement_4  Nb Logement_inverse  \
# 19078        3511808      533794816             0.006579
# 7714         9129329     1908029761             0.004785
# 3753           12167         279841             0.043478
# 10173       13312053     3154956561             0.004219
# 26517      669921875   586181640625             0.001143
#
#        Nb Logement_inverse2  Nb Résidences Secondaires_2  \
# 19078              0.000043                            4
# 7714               0.000023                          144
# 3753               0.001890                           16
# 10173              0.000018                         2601
# 26517              0.000001                           49
#
#        Nb Résidences Secondaires_3  Nb Résidences Secondaires_4  \
# 19078                            8                           16
# 7714                          1728                        20736
# 3753                            64                          256
# 10173                       132651                      6765201
# 26517                          343                         2401
#
#        Nb Résidences Secondaires_inverse  Nb Résidences Secondaires_inverse2  \
# 19078                           0.500000                            0.250000
# 7714                            0.083333                            0.006944
# 3753                            0.250000                            0.062500
# 10173                           0.019608                            0.000384
# 26517                           0.142857                            0.020408
#
#        Nb Log Vacants_2  Nb Log Vacants_3  Nb Log Vacants_4  \
# 19078               324              5832            104976
# 7714                225              3375             50625
# 3753                  1                 1                 1
# 10173                81               729              6561
# 26517               784             21952            614656
#
#        Nb Log Vacants_inverse  Nb Log Vacants_inverse2  \
# 19078                0.055556                 0.003086
# 7714                 0.066667                 0.004444
# 3753                 1.000000                 1.000000
# 10173                0.111111                 0.012346
# 26517                0.035714                 0.001276
#
#        Nb Occupants Résidence Principale_2  \
# 19078                               125316
# 7714                                233289
# 3753                                  1600
# 10173                               207936
# 26517                              5336100
#
#        Nb Occupants Résidence Principale_3  \
# 19078                             44361864
# 7714                             112678587
# 3753                                 64000
# 10173                             94818816
# 26517                          12326391000
#
#        Nb Occupants Résidence Principale_4  \
# 19078                          15704099856
# 7714                           54423757521
# 3753                               2560000
# 10173                          43237380096
# 26517                       28473963210000
#
#        Nb Occupants Résidence Principale_inverse  \
# 19078                                   0.002825
# 7714                                    0.002070
# 3753                                    0.025000
# 10173                                   0.002193
# 26517                                   0.000433
#
#        Nb Occupants Résidence Principale_inverse2  \
# 19078                                7.979827e-06
# 7714                                 4.286529e-06
# 3753                                 6.250000e-04
# 10173                                4.809172e-06
# 26517                                1.874028e-07
#
#        Nb Entreprises Secteur Services_2  Nb Entreprises Secteur Services_3  \
# 19078                               36.0                              216.0
# 7714                                36.0                              216.0
# 3753                                 1.0                                1.0
# 10173                               25.0                              125.0
# 26517                              900.0                            27000.0
#
#        Nb Entreprises Secteur Services_4  \
# 19078                             1296.0
# 7714                              1296.0
# 3753                                 1.0
# 10173                              625.0
# 26517                           810000.0
#
#        Nb Entreprises Secteur Services_inverse  \
# 19078                                 0.166667
# 7714                                  0.166667
# 3753                                  1.000000
# 10173                                 0.200000
# 26517                                 0.033333
#
#        Nb Entreprises Secteur Services_inverse2  \
# 19078                                  0.027778
# 7714                                   0.027778
# 3753                                   1.000000
# 10173                                  0.040000
# 26517                                  0.001111
#
#        Nb Entreprises Secteur Commerce_2  Nb Entreprises Secteur Commerce_3  \
# 19078                               49.0                              343.0
# 7714                                25.0                              125.0
# 3753                                 0.0                                0.0
# 10173                                9.0                               27.0
# 26517                              196.0                             2744.0
#
#        Nb Entreprises Secteur Commerce_4  \
# 19078                             2401.0
# 7714                               625.0
# 3753                                 0.0
# 10173                               81.0
# 26517                            38416.0
#
#        Nb Entreprises Secteur Commerce_inverse  \
# 19078                                 0.142857
# 7714                                  0.200000
# 3753                                       NaN
# 10173                                 0.333333
# 26517                                 0.071429
#
#        Nb Entreprises Secteur Commerce_inverse2  \
# 19078                                  0.020408
# 7714                                   0.040000
# 3753                                        NaN
# 10173                                  0.111111
# 26517                                  0.005102
#
#        Nb Entreprises Secteur Construction_2  \
# 19078                                   36.0
# 7714                                    81.0
# 3753                                     1.0
# 10173                                   16.0
# 26517                                    4.0
#
#        Nb Entreprises Secteur Construction_3  \
# 19078                                  216.0
# 7714                                   729.0
# 3753                                     1.0
# 10173                                   64.0
# 26517                                    8.0
#
#        Nb Entreprises Secteur Construction_4  \
# 19078                                 1296.0
# 7714                                  6561.0
# 3753                                     1.0
# 10173                                  256.0
# 26517                                   16.0
#
#        Nb Entreprises Secteur Construction_inverse  \
# 19078                                     0.166667
# 7714                                      0.111111
# 3753                                      1.000000
# 10173                                     0.250000
# 26517                                     0.500000
#
#        Nb Entreprises Secteur Construction_inverse2  \
# 19078                                      0.027778
# 7714                                       0.012346
# 3753                                       1.000000
# 10173                                      0.062500
# 26517                                      0.250000
#
#        Nb Entreprises Secteur Industrie_2  Nb Entreprises Secteur Industrie_3  \
# 19078                                 9.0                                27.0
# 7714                                 25.0                               125.0
# 3753                                  0.0                                 0.0
# 10173                                49.0                               343.0
# 26517                               225.0                              3375.0
#
#        Nb Entreprises Secteur Industrie_4  \
# 19078                                81.0
# 7714                                625.0
# 3753                                  0.0
# 10173                              2401.0
# 26517                             50625.0
#
#        Nb Entreprises Secteur Industrie_inverse  \
# 19078                                  0.333333
# 7714                                   0.200000
# 3753                                        NaN
# 10173                                  0.142857
# 26517                                  0.066667
#
#        Nb Entreprises Secteur Industrie_inverse2  Nb Création Enteprises_2  \
# 19078                                   0.111111                       1.0
# 7714                                    0.040000                       1.0
# 3753                                         NaN                       0.0
# 10173                                   0.020408                       1.0
# 26517                                   0.004444                       4.0
#
#        Nb Création Enteprises_3  Nb Création Enteprises_4  \
# 19078                       1.0                       1.0
# 7714                        1.0                       1.0
# 3753                        0.0                       0.0
# 10173                       1.0                       1.0
# 26517                       8.0                      16.0
#
#        Nb Création Enteprises_inverse  Nb Création Enteprises_inverse2  \
# 19078                             1.0                             1.00
# 7714                              1.0                             1.00
# 3753                              NaN                              NaN
# 10173                             1.0                             1.00
# 26517                             0.5                             0.25
#
#        Nb Création Industrielles_2  Nb Création Industrielles_3  \
# 19078                          0.0                          0.0
# 7714                           0.0                          0.0
# 3753                           0.0                          0.0
# 10173                          0.0                          0.0
# 26517                          0.0                          0.0
#
#        Nb Création Industrielles_4  Nb Création Industrielles_inverse  \
# 19078                          0.0                                NaN
# 7714                           0.0                                NaN
# 3753                           0.0                                NaN
# 10173                          0.0                                NaN
# 26517                          0.0                                NaN
#
#        Nb Création Industrielles_inverse2  Nb Création Construction_2  \
# 19078                                 NaN                         1.0
# 7714                                  NaN                         1.0
# 3753                                  NaN                         0.0
# 10173                                 NaN                         0.0
# 26517                                 NaN                         0.0
#
#        Nb Création Construction_3  Nb Création Construction_4  \
# 19078                         1.0                         1.0
# 7714                          1.0                         1.0
# 3753                          0.0                         0.0
# 10173                         0.0                         0.0
# 26517                         0.0                         0.0
#
#        Nb Création Construction_inverse  Nb Création Construction_inverse2  \
# 19078                               1.0                                1.0
# 7714                                1.0                                1.0
# 3753                                NaN                                NaN
# 10173                               NaN                                NaN
# 26517                               NaN                                NaN
#
#        Nb Création Commerces_2  Nb Création Commerces_3  \
# 19078                      0.0                      0.0
# 7714                       0.0                      0.0
# 3753                       0.0                      0.0
# 10173                      0.0                      0.0
# 26517                      1.0                      1.0
#
#        Nb Création Commerces_4  Nb Création Commerces_inverse  \
# 19078                      0.0                            NaN
# 7714                       0.0                            NaN
# 3753                       0.0                            NaN
# 10173                      0.0                            NaN
# 26517                      1.0                            1.0
#
#        Nb Création Commerces_inverse2  Nb Création Services_2  \
# 19078                             NaN                     0.0
# 7714                              NaN                     0.0
# 3753                              NaN                     0.0
# 10173                             NaN                     1.0
# 26517                             1.0                     1.0
#
#        Nb Création Services_3  Nb Création Services_4  \
# 19078                     0.0                     0.0
# 7714                      0.0                     0.0
# 3753                      0.0                     0.0
# 10173                     1.0                     1.0
# 26517                     1.0                     1.0
#
#        Nb Création Services_inverse  Nb Création Services_inverse2  \
# 19078                           NaN                            NaN
# 7714                            NaN                            NaN
# 3753                            NaN                            NaN
# 10173                           1.0                            1.0
# 26517                           1.0                            1.0
#
#        Moyenne Revenus Fiscaux Départementaux_2  \
# 19078                                  97219600
# 7714                                  212693056
# 3753                                   87684496
# 10173                                  44729344
# 26517                                  80389156
#
# ...
# 29268                                                NaN
# 217                                                  NaN
# 15576                                              0.200
#
#        Pop 15 ans ou plus Agriculteurs exploitants en 2014 (compl)_inverse2  \
# 32508                                                NaN
# 6252                                            0.015625
# 29268                                                NaN
# 217                                                  NaN
# 15576                                           0.040000
#
#        Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_2  \
# 32508                                            22801.0
# 6252                                                64.0
# 29268                                             5476.0
# 217                                                  0.0
# 15576                                              576.0
#
#        Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_3  \
# 32508                                          3442951.0
# 6252                                               512.0
# 29268                                           405224.0
# 217                                                  0.0
# 15576                                            13824.0
#
#        Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_4  \
# 32508                                        519885601.0
# 6252                                              4096.0
# 29268                                         29986576.0
# 217                                                  0.0
# 15576                                           331776.0
#
#        Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_inverse  \
# 32508                                           0.006623
# 6252                                            0.125000
# 29268                                           0.013514
# 217                                                  NaN
# 15576                                           0.041667
#
#        Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2014 (compl)_inverse2  \
# 32508                                           0.000044
# 6252                                            0.015625
# 29268                                           0.000183
# 217                                                  NaN
# 15576                                           0.001736
#
#        Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_2  \
# 32508                                           140625.0
# 6252                                                16.0
# 29268                                             9604.0
# 217                                                  0.0
# 15576                                             5184.0
#
#        Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_3  \
# 32508                                         52734375.0
# 6252                                                64.0
# 29268                                           941192.0
# 217                                                  0.0
# 15576                                           373248.0
#
#        Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_4  \
# 32508                                       1.977539e+10
# 6252                                        2.560000e+02
# 29268                                       9.223682e+07
# 217                                         0.000000e+00
# 15576                                       2.687386e+07
#
#        Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_inverse  \
# 32508                                           0.002667
# 6252                                            0.250000
# 29268                                           0.010204
# 217                                                  NaN
# 15576                                           0.013889
#
#        Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2014 (compl)_inverse2  \
# 32508                                           0.000007
# 6252                                            0.062500
# 29268                                           0.000104
# 217                                                  NaN
# 15576                                           0.000193
#
#        Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_2  \
# 32508                                            68121.0
# 6252                                               400.0
# 29268                                            70225.0
# 217                                                256.0
# 15576                                             8281.0
#
#        Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_3  \
# 32508                                         17779581.0
# 6252                                              8000.0
# 29268                                         18609625.0
# 217                                               4096.0
# 15576                                           753571.0
#
#        Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_4  \
# 32508                                       4.640471e+09
# 6252                                        1.600000e+05
# 29268                                       4.931551e+09
# 217                                         6.553600e+04
# 15576                                       6.857496e+07
#
#        Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_inverse  \
# 32508                                           0.003831
# 6252                                            0.050000
# 29268                                           0.003774
# 217                                             0.062500
# 15576                                           0.010989
#
#        Pop 15 ans ou plus Prof. intermédiaires  en 2014 (compl)_inverse2  \
# 32508                                           0.000015
# 6252                                            0.002500
# 29268                                           0.000014
# 217                                             0.003906
# 15576                                           0.000121
#
#        Pop 15 ans ou plus Employés en 2014 (compl)_2  \
# 32508                                        25281.0
# 6252                                          2209.0
# 29268                                        67600.0
# 217                                            121.0
# 15576                                         5184.0
#
#        Pop 15 ans ou plus Employés en 2014 (compl)_3  \
# 32508                                      4019679.0
# 6252                                        103823.0
# 29268                                     17576000.0
# 217                                           1331.0
# 15576                                       373248.0
#
#        Pop 15 ans ou plus Employés en 2014 (compl)_4  \
# 32508                                   6.391290e+08
# 6252                                    4.879681e+06
# 29268                                   4.569760e+09
# 217                                     1.464100e+04
# 15576                                   2.687386e+07
#
#        Pop 15 ans ou plus Employés en 2014 (compl)_inverse  \
# 32508                                           0.006289
# 6252                                            0.021277
# 29268                                           0.003846
# 217                                             0.090909
# 15576                                           0.013889
#
#        Pop 15 ans ou plus Employés en 2014 (compl)_inverse2  \
# 32508                                           0.000040
# 6252                                            0.000453
# 29268                                           0.000015
# 217                                             0.008264
# 15576                                           0.000193
#
#        Pop 15 ans ou plus Ouvriers en 2014 (compl)_2  \
# 32508                                         4225.0
# 6252                                           729.0
# 29268                                        65025.0
# 217                                            256.0
# 15576                                         3364.0
#
#        Pop 15 ans ou plus Ouvriers en 2014 (compl)_3  \
# 32508                                       274625.0
# 6252                                         19683.0
# 29268                                     16581375.0
# 217                                           4096.0
# 15576                                       195112.0
#
#        Pop 15 ans ou plus Ouvriers en 2014 (compl)_4  \
# 32508                                   1.785062e+07
# 6252                                    5.314410e+05
# 29268                                   4.228251e+09
# 217                                     6.553600e+04
# 15576                                   1.131650e+07
#
#        Pop 15 ans ou plus Ouvriers en 2014 (compl)_inverse  \
# 32508                                           0.015385
# 6252                                            0.037037
# 29268                                           0.003922
# 217                                             0.062500
# 15576                                           0.017241
#
#        Pop 15 ans ou plus Ouvriers en 2014 (compl)_inverse2  \
# 32508                                           0.000237
# 6252                                            0.001372
# 29268                                           0.000015
# 217                                             0.003906
# 15576                                           0.000297
#
#        Pop 15 ans ou plus Retraités  en 2014 (compl)_2  \
# 32508                                         426409.0
# 6252                                            8100.0
# 29268                                         222784.0
# 217                                             4761.0
# 15576                                          19321.0
#
#        Pop 15 ans ou plus Retraités  en 2014 (compl)_3  \
# 32508                                      278445077.0
# 6252                                          729000.0
# 29268                                      105154048.0
# 217                                           328509.0
# 15576                                        2685619.0
#
#        Pop 15 ans ou plus Retraités  en 2014 (compl)_4  \
# 32508                                     1.818246e+11
# 6252                                      6.561000e+07
# 29268                                     4.963271e+10
# 217                                       2.266712e+07
# 15576                                     3.733010e+08
#
#        Pop 15 ans ou plus Retraités  en 2014 (compl)_inverse  \
# 32508                                           0.001531
# 6252                                            0.011111
# 29268                                           0.002119
# 217                                             0.014493
# 15576                                           0.007194
#
#        Pop 15 ans ou plus Retraités  en 2014 (compl)_inverse2  \
# 32508                                           0.000002
# 6252                                            0.000123
# 29268                                           0.000004
# 217                                             0.000210
# 15576                                           0.000052
#
#        Pop 15 ans ou plus Autres en 2014 (compl)_2  \
# 32508                                      74529.0
# 6252                                          64.0
# 29268                                      23104.0
# 217                                           25.0
# 15576                                        841.0
#
#        Pop 15 ans ou plus Autres en 2014 (compl)_3  \
# 32508                                   20346417.0
# 6252                                         512.0
# 29268                                    3511808.0
# 217                                          125.0
# 15576                                      24389.0
#
#        Pop 15 ans ou plus Autres en 2014 (compl)_4  \
# 32508                                 5.554572e+09
# 6252                                  4.096000e+03
# 29268                                 5.337948e+08
# 217                                   6.250000e+02
# 15576                                 7.072810e+05
#
#        Pop 15 ans ou plus Autres en 2014 (compl)_inverse  \
# 32508                                           0.003663
# 6252                                            0.125000
# 29268                                           0.006579
# 217                                             0.200000
# 15576                                           0.034483
#
#        Pop 15 ans ou plus Autres en 2014 (compl)_inverse2  \
# 32508                                           0.000013
# 6252                                            0.015625
# 29268                                           0.000043
# 217                                             0.040000
# 15576                                           0.001189
#
#        taux chômage(15-64 ans)_2  taux chômage(15-64 ans)_3  \
# 32508                  73.141106                 625.521564
# 6252                   94.118957                 913.094363
# 29268                  58.794108                 450.817444
# 217                    64.000000                 512.000000
# 15576                  82.644628                 751.314801
#
#        taux chômage(15-64 ans)_4  taux chômage(15-64 ans)_inverse  \
# 32508                5349.621403                         0.116928
# 6252                 8858.378152                         0.103077
# 29268                3456.747176                         0.130417
# 217                  4096.000000                         0.125000
# 15576                6830.134554                         0.110000
#
#        taux chômage(15-64 ans)_inverse2
# 32508                          0.013672
# 6252                           0.010625
# 29268                          0.017009
# 217                            0.015625
# 15576                          0.012100
# ...Done.
# [[ 0.08841262  0.08060144  0.15665824 ...  0.          0.
#    0.        ]
#  [-0.17281434 -0.13564649 -0.21916618 ...  0.          0.
#    1.        ]
#  [-0.08518757 -0.07637041 -0.11502206 ...  1.          0.
#    0.        ]
#  [-0.12321428 -0.13674419 -0.05162999 ...  0.          1.
#    0.        ]
#  [-0.09345425 -0.11918091  0.03893011 ...  0.          1.
#    0.        ]]

# %%
column_names = preprocessor.get_feature_names_out()

# %%
# Train model
model = LinearRegression()
print("Training model...")
model.fit(X_train, Y_train)  # Training is always done on train set !!
print("...Done.")
# Out:
# Training model...
# ...Done.

# %%
# Print R^2 scores
print("R2 score on training set : ", model.score(X_train, Y_train))
print("R2 score on test set : ", model.score(X_test, Y_test))
# Out:
# R2 score on training set :  0.3148502653159022
# R2 score on test set :  -1.448227060365256

# %% [markdown]
# ## Forward selection

# %%
from sklearn.feature_selection import  SequentialFeatureSelector
feature_selector =  SequentialFeatureSelector(model, n_features_to_select = 10)
feature_selector.fit(X_train, Y_train)
#features_list = X.columns
#best_features = features_list[feature_selector.support_]
print("According to the forward selection algorithm, the following features should be kept: ")
print(feature_selector.support_.tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 from sklearn.feature_selection import  SequentialFeatureSelector
#       2 feature_selector =  SequentialFeatureSelector(model, n_features_to_select = 10)
# ----> 3 feature_selector.fit(X_train, Y_train)
#       4 #features_list = X.columns
#       5 #best_features = features_list[feature_selector.support_]
#       6 print("According to the forward selection algorithm, the following features should be kept: ")
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\feature_selection\_sequential.py:246, in SequentialFeatureSelector.fit(self, X, y)
#     244 is_auto_select = self.tol is not None and self.n_features_to_select == "auto"
#     245 for _ in range(n_iterations):
# --> 246     new_feature_idx, new_score = self._get_best_new_feature_score(
#     247         cloned_estimator, X, y, cv, current_mask
#     248     )
#     249     if is_auto_select and ((new_score - old_score) < self.tol):
#     250         break
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\feature_selection\_sequential.py:277, in SequentialFeatureSelector._get_best_new_feature_score(self, estimator, X, y, cv, current_mask)
#     275         candidate_mask = ~candidate_mask
#     276     X_new = X[:, candidate_mask]
# --> 277     scores[feature_idx] = cross_val_score(
#     278         estimator,
#     279         X_new,
#     280         y,
#     281         cv=cv,
#     282         scoring=self.scoring,
#     283         n_jobs=self.n_jobs,
#     284     ).mean()
#     285 new_feature_idx = max(scores, key=lambda feature_idx: scores[feature_idx])
#     286 return new_feature_idx, scores[new_feature_idx]
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:562, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     559 # To ensure multimetric format is not supported
#     560 scorer = check_scoring(estimator, scoring=scoring)
# --> 562 cv_results = cross_validate(
#     563     estimator=estimator,
#     564     X=X,
#     565     y=y,
#     566     groups=groups,
#     567     scoring={"score": scorer},
#     568     cv=cv,
#     569     n_jobs=n_jobs,
#     570     verbose=verbose,
#     571     fit_params=fit_params,
#     572     pre_dispatch=pre_dispatch,
#     573     error_score=error_score,
#     574 )
#     575 return cv_results["test_score"]
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:309, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     306 # We clone the estimator to make sure that all the folds are
#     307 # independent, and that it is pickle-able.
#     308 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 309 results = parallel(
#     310     delayed(_fit_and_score)(
#     311         clone(estimator),
#     312         X,
#     313         y,
#     314         scorers,
#     315         train,
#     316         test,
#     317         verbose,
#     318         None,
#     319         fit_params,
#     320         return_train_score=return_train_score,
#     321         return_times=True,
#     322         return_estimator=return_estimator,
#     323         error_score=error_score,
#     324     )
#     325     for train, test in indices
#     326 )
#     328 _warn_or_raise_about_fit_failures(results, error_score)
#     330 # For callable scoring, the return type is only know after calling. If the
#     331 # return type is a dictionary, the error scores can now be inserted with
#     332 # the correct key.
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:732, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     730         estimator.fit(X_train, **fit_params)
#     731     else:
# --> 732         estimator.fit(X_train, y_train, **fit_params)
#     734 except Exception:
#     735     # Note fit time as time until error
#     736     fit_time = time.time() - start_time
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:751, in LinearRegression.fit(self, X, y, sample_weight)
#     749         self.coef_ = np.vstack([out[0] for out in outs])
#     750 else:
# --> 751     self.coef_, _, self.rank_, self.singular_ = linalg.lstsq(X, y)
#     752     self.coef_ = self.coef_.T
#     754 if y.ndim == 1:
#
# File c:\Users\alexa\anaconda3\Lib\site-packages\scipy\linalg\_basic.py:1294, in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#    1291 if info < 0:
#    1292     raise ValueError('illegal value in %d-th argument of internal %s'
#    1293                      % (-info, lapack_driver))
# -> 1294 resids = np.asarray([], dtype=x.dtype)
#    1295 if m > n:
#    1296     x1 = x[:n]
#
# KeyboardInterrupt:

# %%
# Get the indices of the selected features
selected_feature_indices = feature_selector.get_support(indices=True)

# Use these indices to filter the corresponding column names
selected_column_names = [column_names[i] for i in selected_feature_indices]

# Print the names of the selected features
print("The names of the selected features are:", selected_column_names)

# %%
# Initialize the filtered list
temp_final_features = []
final_features = []

# Iterate through the example list
for element in selected_column_names:
    if element.startswith("num__"):
        # If the element starts with "num__", keep it as is
        temp_final_features.append(element)
    elif element.startswith("cat__"):
        # If the element starts with "cat__", find the index of the last underscore
        last_underscore_index = element.rfind('_')
        # Keep only the part of the element up to the last underscore
        filtered_element = element[:last_underscore_index]
        # Add the filtered element to the filtered list
        temp_final_features.append(filtered_element)

for element in temp_final_features:
    # Checkif the element is already in the list
    if element not in final_features:
        # If the element is not in the list, add it
        final_features.append(element)

final_features = [name[5:] for name in final_features]

# Print the filtered list
print("Filtered List:", final_features)

# %%
insee_best = insee_df[final_features + ["APL"]]

# %%
print('Number of rows :', insee_best.shape[0])
print('Number of columns :', insee_best.shape[1])
print()

# Show first rows of the dataset
print('First rows of the dataset :')
display(insee_best.head())
print()

# Dataset statistics
print('Basics statistics :')
summary_stats_all = insee_best.describe(include='all')
display(summary_stats_all)
print()

# Missing values percentage
missing_percentages = (insee_best.isna().mean() * 100).round(2)
print('Percentage of missing values: ')
print(missing_percentages)

# %%
# Separate target variable Y from features X
print("Separating labels from features...")
target_variable = "APL"

X = insee_best.drop(target_variable, axis = 1)
Y = insee_best.loc[:,target_variable]

print("...Done.")
print()

print('Y : ')
print(Y.head())
print()
print('X :')
X.head()

# %%
#Train-test splitting

print("Dividing into train and test sets...")
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print("...Done.")
print()

# %%
# Automatically detect names of numeric/categorical columns
numeric_features = []
categorical_features = []
for i, t in X.dtypes.items():
    if ('float' in str(t)) or ('int' in str(t)):
        numeric_features.append(i)
    else:
        categorical_features.append(i)
print('Found numeric features ', numeric_features)
print('Found categorical features ', categorical_features)

# %%
#Multiple Transformations preprocessing

# Create pipeline for numeric features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')), # missing values will be replaced by columns' mean
    ('scaler', StandardScaler())
])

# Create pipeline for categorical features
categorical_transformer = Pipeline(
    steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')), # missing values will be replaced by most frequent value
    ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore')) # first column will be dropped to avoid creating correlations between features
    ])

# Use ColumnTransformer to make a preprocessor object that describes all the treatments to be done
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# %%
# Preprocessings on train set
print("Performing preprocessings on train set...")
print(X_train.head())
X_train = preprocessor.fit_transform(X_train)
print('...Done.')
print(X_train[0:5,:])
print()

# Preprocessings on test set
print("Performing preprocessings on test set...")
print(X_test.head())
X_test = preprocessor.transform(X_test) # Don't fit again !!
print('...Done.')
print(X_test[0:5,:])
print()

# %%
# Train model
model = LinearRegression()
print("Training model...")
model.fit(X_train, Y_train)  # Training is always done on train set !!
print("...Done.")

# %%
# Print R^2 scores
print("R2 score on training set : ", model.score(X_train, Y_train))
print("R2 score on test set : ", model.score(X_test, Y_test))

# %%
column_names = []
for name, pipeline, features_list in preprocessor.transformers_: # loop over pipelines
    if name == 'num': # if pipeline is for numeric variables
        features = features_list # just get the names of columns to which it has been applied
    else: # if pipeline is for categorical variables
        features = pipeline.named_steps['encoder'].get_feature_names_out() # get output columns names from OneHotEncoder
    column_names.extend(features) # concatenate features names
        
print("Names of columns corresponding to each coefficient: ", column_names)

# Create a pandas DataFrame
coefs = pd.DataFrame(index = column_names, data = model.coef_.transpose(), columns=["coefficients"])
coefs

# Compute abs() and sort values
feature_importance = abs(coefs).sort_values(by = 'coefficients')
feature_importance

# Plot coefficients
fig = px.bar(feature_importance, orientation = 'h')
fig.update_layout(showlegend = False, 
                  margin = {'l': 120} # to avoid cropping of column names
                 )

fig.update_layout(height=2400, width=1600)

fig.show()
